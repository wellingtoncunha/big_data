# %%
import pandas as pd
import os

# %%
base_folder = os.getcwd()

# %% [markdown]
# ### Load Training Dataset
#
# The following function loads the training file and split it into training and test datasets
#
# It received the following args:
#
# * **sample_size**: the amount of rows from the file that we want to load. The whole file has 1.6MM of rows and it is unpractical to work with this amount on a local machine. For the final training with the whole dataset, a Hadoop cliuster are advised. If the arg is not informed, the function will return all the lines into two lists of dicts: one for training and another for testing
# * **test_size_frac**: the fraction of lines that will be reserved for testing the model
#
# **Note**: we are converting the Pandas DataFrame to a list of dict because nltk package does not work with Pandas

# %%
def load_training_dataset(sample_size = None, test_size_frac = 0.5):
    training_dataset_path = os.path.join(
        base_folder, 
        "trainingandtestdata", 
        "training.1600000.processed.noemoticon.csv")

    training_dataset = pd.read_csv(
        training_dataset_path, 
        encoding="latin-1", 
        warn_bad_lines=True,
        error_bad_lines=False,
        header=None, 
        names=["polarity", "tweet_id", "date", "query", "user", "tweet"])
    if sample_size != None:
        training_dataset = training_dataset.sample(sample_size)

    #training_dataset = training_dataset[["tweet_id", "polarity", "tweet"]]
    
    testing_dataset = training_dataset.sample(frac = test_size_frac)

    training_dataset = training_dataset.drop(testing_dataset.index)
 
    return training_dataset.to_dict("records"), testing_dataset.to_dict("records")

# %%
# Load test and training dataset for exploration
training_data, testing_data = load_training_dataset(sample_size = None, test_size_frac=.5)

# %%
pd.DataFrame(training_data).head(10)
# Out:
#    polarity    tweet_id                          date     query  \
# 0         0  1467810369  Mon Apr 06 22:19:45 PDT 2009  NO_QUERY
# 1         0  1467810672  Mon Apr 06 22:19:49 PDT 2009  NO_QUERY
# 2         0  1467811592  Mon Apr 06 22:20:03 PDT 2009  NO_QUERY
# 3         0  1467811795  Mon Apr 06 22:20:05 PDT 2009  NO_QUERY
# 4         0  1467812025  Mon Apr 06 22:20:09 PDT 2009  NO_QUERY
# 5         0  1467812416  Mon Apr 06 22:20:16 PDT 2009  NO_QUERY
# 6         0  1467812579  Mon Apr 06 22:20:17 PDT 2009  NO_QUERY
# 7         0  1467812771  Mon Apr 06 22:20:19 PDT 2009  NO_QUERY
# 8         0  1467812964  Mon Apr 06 22:20:22 PDT 2009  NO_QUERY
# 9         0  1467813137  Mon Apr 06 22:20:25 PDT 2009  NO_QUERY
#
#               user                                              tweet
# 0  _TheSpecialOne_  @switchfoot http://twitpic.com/2y1zl - Awww, t...
# 1    scotthamilton  is upset that he can't update his Facebook by ...
# 2          mybirch                                        Need a hug
# 3  2Hood4Hollywood               @Tatiana_K nope they didn't have it
# 4          mimismo                          @twittera que me muera ?
# 5   erinx3leannexo        spring break in plain city... it's snowing
# 6     pardonlauren                         I just re-pierced my ears
# 7  robrobbierobert  @octolinz16 It it counts, idk why I did either...
# 8   lovesongwriter  Hollis' death scene will hurt me severely to w...
# 9         armotley                               about to file taxes

# %% [markdown]
# Column definitions:
#
# 0 - the polarity of the tweet (0 = negative, 2 = neutral, 4 = positive)
#
# 1 - the id of the tweet
#
# 2 - the date of the tweet
#
# 3 - the query. If there is no query, then this value is NO_QUERY.
#
# 5 - the text of the tweet

# %%
# We noticed that there is not a single case of Neutral (2) polarity
pd.DataFrame(training_data + testing_data).polarity.value_counts()
# Out:
# 4    800000
# 0    800000
# Name: polarity, dtype: int64

# %% [markdown]
# ### Pre-process Tweets
#
# The following class prepares the dataset by:
#
# * Extracting the text from HTML (for the training dataset provided, we already have the text, but we want to avoid using any HTML tag for classification
# * Converting all words to lower case
# * Replacing any URL with "URL" constant (to enable the removal of them on a further step)
# * Replacing any tagging of users with "USERTAGGING" (to enable the removal of them in a further step)
# * Removing any "#" from hashtags
# * Removing punctuation (has little or no weight on classification as it can be used for both intentions)
# * Tokenizing (create a list of words)
# * And finally, removing words and punctuation that has little or no weight on classification (and can even create biases):
#     * Stop words: set of common words that are used doesn't matter the intenttion (things like it, that, a, the)
#     * Remove the two constants that we used to replace user tagging and URLs
#
# **Note**: we are creating a class for this process because we want to "pickle" (serialize and save as a file) it for usage on the implementation of the streaming process

# %%
import re
from nltk.tokenize import word_tokenize
from string import punctuation 
from nltk.corpus import stopwords 
from bs4 import BeautifulSoup

class PreProcessTweets:
    def __init__(self):
        self._stopwords = set(stopwords.words("english") + ["USERTAGGING","URL"])
        
    def processTweets(self, list_of_tweets):
        processedTweets=[]
        for tweet in list_of_tweets:
            processedTweets.append(
                (
                    self.processTweet(tweet["tweet"]),
                    tweet["polarity"]                    
                )
            )
        return processedTweets
    
    def processTweet(self, tweet):
        tweet = BeautifulSoup(tweet).get_text() # Extracts text from HTML (just in case!)
        tweet = tweet.lower() # Converts text to lower-case
        tweet = re.sub("((www\.[^\s]+)|(https?://[^\s]+))", "URL", tweet) # Replces URLs by URL constan
        tweet = re.sub("@[^\s]+", "USERTAGGING", tweet) # Replaces usernames by USERTAGGING constant 
        tweet = re.sub(r"#([^\s]+)", r"\1", tweet) # Removes the # in #hashtag
        for p in punctuation: 
            tweet = tweet.replace(p, "") # Removes punctiation
        tweet = word_tokenize(tweet) # Creates a list of words
        return [word for word in tweet if word not in self._stopwords]

# %%
# Load test and training dataset for modeling
training_data, testing_data = load_training_dataset(sample_size = 10000, test_size_frac=.5)

# %%
#Preprocessing Tweets
tweet_processor = PreProcessTweets()
pp_training_data = tweet_processor.processTweets(training_data)

# %%
# Let's take a look on how some tweets look like after cleansing and tokenization
pp_training_data[:4]
# Out:
# [(['agree'], 4),
#  (['crazy', 'good', 'news'], 4),
#  (['numbers', 'arent', 'everything'], 4),
#  (['got', 'passed', 'mopedwe', 'cant', 'friends', 'anymore', 'lol'], 0)]

# %% [markdown]
# ### Build Vocabulary
#
# The function below builds the vocabulary, it means the list of all words that we are going to use to train our model and later use to evaluate the tweet
#
# Some people argues that it is better to focus on the most used words (e.g. 2500 most used in our training dataset) and/or the words more present on documents (in our case tweets - like the words that are more present in more tweets)
#
# For the sake of this project, as it is not focused on the assertiveness of the model itself, but in the implementation of a pipeline using a model, we are going to use all words

# %%
import nltk 

def build_vocabulary(preprocessed_training_dataset):
    all_words = []
    
    for (words, polarity) in preprocessed_training_dataset:
        all_words.extend(words)

    word_list = nltk.FreqDist(all_words)
    word_features = word_list.keys()
    
    return word_features

# %%
# Then we build our vocabulary
word_features = build_vocabulary(pp_training_data)

# %%
# and let's take a look on it:
word_features
# Out:
# dict_keys(['agree', 'crazy', 'good', 'news', 'numbers', 'arent', 'everything', 'got', 'passed', 'mopedwe', 'cant', 'friends', 'anymore', 'lol', 'great', 'weekend', 'much', 'fun', 'ha', 'wait', 'hear', 'mileys', 'hugeee', 'announcement', 'ahaha', 'kk', 'either', 'yeah', 'im', 'going', 'tai', 'anberlin', 'melb', 'one', 'sydney', 'haha', 'well', 'add', 'mom', 'list', 'sweet', 'game', 'finally', 'home', 'super', 'tired', 'gon', 'na', 'watch', 'movie', 'wit', 'lover', 'hehe', 'sleep', 'ta', 'work', 'tomorrow', 'sad', 'hate', 'beauty', 'spoiled', 'destroyed', 'entirely', 'irrevirsible', 'aw', 'last', 'week', 'told', 'son', 'would', 'take', 'chuck', 'e', 'cheese', 'went', 'start', 'car', 'dead', 'battery', 'felt', 'bad', 'love', 'guys', 'currently', 'waitin', 'call', 'kic', 'tonite', 'havent', 'seen', 'indeed', 'sure', 'rock', 'day', 'pretty', 'bummed', 'make', 'ignite', 'phoenix', 'event', 'tonight', 'hopefully', 'next', 'yes', 'okay', 'monday', 'situps', 'today', 'lots', 'trains', 'dont', 'run', 'sunday', 'missed', 'previous', 'train', '5', 'mins', 'waiting', 'hour', 'aiming', 'r2picnic', '2', 'hoooney', 'jst', 'knw', 'u', 'b', 'didnt', 'even', 'thnk', 'hit', 'asha', 'first', 'way', '845am', 'hangin', 'saaaammmm', 'like', 'fact', 'gay', 'best', 'friend', 'tears', 'â\x99¥', 'afternoon', 'twitterville', 'hope', 'everyone', 'beautiful', 'guess', 'yogurt', 'cheap', 'night', 'walnut', 'hills', 'kroger', 'expires', 'thing', 'bought', '10', 'mean', 'scholarship', 'go', 'back', 'plz', 'stretching', 'ears', 'upto', '10mm', 'started', 'wednesday', '6mm', '5mm', 'far', 'said', 'hi', 'como', 'estas', 'hows', 'geewon', 'ill', 'pic', 'r', 'excited', 'hopes', 'seeing', 'sharkies', 'keys', 'sea', 'turtles', 'ive', 'learned', 'videoreview', 'really', 'follow', 'videogames', 'want', 'though', 'freakin', 'pissed', 'intensive', 'readinq', 'year', 'elective', 'prestonia', 'birthday', 'drinkies', 'w00t', 'p', 'came', 'nice', 'bbq', 'neighbors', 'times', 'youre', 'right', 'change', 'team', 'shirts', 'actually', 'another', 'shirt', 'may', 'need', 'logos', 'miss', 'keep', 'missing', 'part', '1', 'ladies', 'detective', 'agency', 'fyi', 'lobby', 'reconstruction', 'freak', 'found', 'caffine', 'henders', 'ability', 'woman', 'orgasm', 'hey', 'cognackid', 'glad', 'grace', 'puts', 'coz', 'boring', 'bc', 'comforting', 'taking', 'applications', 'new', '1887', 'constitution', 'signed', 'swimming', 'cut', 'short', 'stupid', 'freshmen', 'pe', 'class', 'lap', 'dreading', 'exams', 'tomoro', 'aspects', 'life', 'people', 'angry', 'bed', 'cba', 'gah', 'blister', 'hurts', 'pretty3', 'shopping', 'loved', 'sunny', 'wasted', 'away', 'classes', 'congrats', 'jealous', 'stuck', 'crowd', '100000000000000', 'talented', 'breathtakingly', 'tour', 'prays', 'brings', 'forth', 'open', 'hearts', 'let', 'speak', 'selfish', 'voting', 'never', 'helped', 'anybody', 'excellent', 'ho', 'hum', 'quite', 'god', 'save', 'king', 'fellaini', 'brotherinfros', 'happy', 'twitterversary', 'hanging', 'nursing', 'hahaha', 'olive', 'thanks', 'wow', 'acoustic', 'version', 'collide', 'howie', 'fantasticharmonising', 'editing', 'feels', 'spoke', 'siser', 'jus', 'ass', 'hell', 'still', 'page', 'paper', 'write', 'smh', 'please', 'youll', 'wonderful', 'sat', 'office', 'revising', 'tomorrows', 'exam', 'aaaaaaadn', 'ville', 'totally', 'breakfast', 'later', 'wanted', 'interview', 'internetweek', 'state', 'origin', 'lost', 'chichester', 'replies', 'cltwin', 'pls', 'give', 'xoxoxo', 'tina', 'bored', 'learning', 'database', 'yay', 'spilled', 'smart', 'water', 'happen', 'allright', 'kenny', 'lattimore', 'friendly', 'guy', 'nigga', 'smokin', 'black', 'somebody', 'ima', 'curse', 'feelings', 'pay', 'money', 'name', 'building', 'reference', 'aac', 'script', 'breakeven', 'â\x99', '«', 'record', 'todaymatt', 'nathanson', 'tracks', 'post', 'oh', 'already', 'trouble', 'controlling', 'excitement', 'upcoming', 'trip', '9', 'days', 'chilling', 'lauren', 'surprise', 'shuddup', 'dentisit', 'demi', 'girl', 'trying', 'vote', 'freakin ...

# %% [markdown]
# ### Generating Features
# The function below needs to be called for each one of the tweets and basically tags (with True) on a instance of the dictionary previously built which words in that instance of the dictionary that are used in that specific tweet. Thus, the majority of words will ba tagged as False and a small number of them (the ones contained in the tweet) as True
#
# **To-do**: this should also be encapsulated on a class in order to have it pickled. Or maybe encapsulate the whole code?!?!?

# %%
def extract_features(tweet):
    tweet_words=set(tweet)
    features={}
    for word in word_features:
        features['contains(%s)' % word]=(word in tweet_words)
    return features

# %%
# Building the training features
training_features = nltk.classify.apply_features(extract_features,pp_training_data)

# %%
# And taking a look into it
training_features
# Out:
# [({'contains(agree)': True, 'contains(crazy)': False, 'contains(good)': False, 'contains(news)': False, 'contains(numbers)': False, 'contains(arent)': False, 'contains(everything)': False, 'contains(got)': False, 'contains(passed)': False, 'contains(mopedwe)': False, 'contains(cant)': False, 'contains(friends)': False, 'contains(anymore)': False, 'contains(lol)': False, 'contains(great)': False, 'contains(weekend)': False, 'contains(much)': False, 'contains(fun)': False, 'contains(ha)': False, 'contains(wait)': False, 'contains(hear)': False, 'contains(mileys)': False, 'contains(hugeee)': False, 'contains(announcement)': False, 'contains(ahaha)': False, 'contains(kk)': False, 'contains(either)': False, 'contains(yeah)': False, 'contains(im)': False, 'contains(going)': False, 'contains(tai)': False, 'contains(anberlin)': False, 'contains(melb)': False, 'contains(one)': False, 'contains(sydney)': False, 'contains(haha)': False, 'contains(well)': False, 'contains(add)': False, 'contains(mom)': False, 'contains(list)': False, 'contains(sweet)': False, 'contains(game)': False, 'contains(finally)': False, 'contains(home)': False, 'contains(super)': False, 'contains(tired)': False, 'contains(gon)': False, 'contains(na)': False, 'contains(watch)': False, 'contains(movie)': False, 'contains(wit)': False, 'contains(lover)': False, 'contains(hehe)': False, 'contains(sleep)': False, 'contains(ta)': False, 'contains(work)': False, 'contains(tomorrow)': False, 'contains(sad)': False, 'contains(hate)': False, 'contains(beauty)': False, 'contains(spoiled)': False, 'contains(destroyed)': False, 'contains(entirely)': False, 'contains(irrevirsible)': False, 'contains(aw)': False, 'contains(last)': False, 'contains(week)': False, 'contains(told)': False, 'contains(son)': False, 'contains(would)': False, 'contains(take)': False, 'contains(chuck)': False, 'contains(e)': False, 'contains(cheese)': False, 'contains(went)': False, 'contains(start)': False, 'contains(car)': False, 'contains(dead)': False, 'contains(battery)': False, 'contains(felt)': False, 'contains(bad)': False, 'contains(love)': False, 'contains(guys)': False, 'contains(currently)': False, 'contains(waitin)': False, 'contains(call)': False, 'contains(kic)': False, 'contains(tonite)': False, 'contains(havent)': False, 'contains(seen)': False, 'contains(indeed)': False, 'contains(sure)': False, 'contains(rock)': False, 'contains(day)': False, 'contains(pretty)': False, 'contains(bummed)': False, 'contains(make)': False, 'contains(ignite)': False, 'contains(phoenix)': False, 'contains(event)': False, 'contains(tonight)': False, 'contains(hopefully)': False, 'contains(next)': False, 'contains(yes)': False, 'contains(okay)': False, 'contains(monday)': False, 'contains(situps)': False, 'contains(today)': False, 'contains(lots)': False, 'contains(trains)': False, 'contains(dont)': False, 'contains(run)': False, 'contains(sunday)': False, 'contains(missed)': False, 'contains(previous)': False, 'contains(train)': False, 'contains(5)': False, 'contains(mins)': False, 'contains(waiting)': False, 'contains(hour)': False, 'contains(aiming)': False, 'contains(r2picnic)': False, 'contains(2)': False, 'contains(hoooney)': False, 'contains(jst)': False, 'contains(knw)': False, 'contains(u)': False, 'contains(b)': False, 'contains(didnt)': False, 'contains(even)': False, 'contains(thnk)': False, 'contains(hit)': False, 'contains(asha)': False, 'contains(first)': False, 'contains(way)': False, 'contains(845am)': False, 'contains(hangin)': False, 'contains(saaaammmm)': False, 'contains(like)': False, 'contains(fact)': False, 'contains(gay)': False, 'contains(best)': False, 'contains(friend)': False, 'contains(tears)': False, 'contains(â\x99¥)': False, 'contains(afternoon)': False, 'contains(twitterville)': False, 'contains(hope)': False, 'contains(everyone)': False, 'contains(beautiful)': False, 'contains(guess)': False, 'contains(yogurt)': False, 'contains(cheap)': False, 'contains(night)': False, 'co ...

# %% [markdown]
# ### Training the model
# And finally, we are going to train the model using Naive Bayes. We could have tried other classification algorithms but again, the main purpose of this project is the implementation of the pipeline, not the accuracy of the model

# %%
NBayesClassifier = nltk.NaiveBayesClassifier.train(training_features)

# %% [markdown]
# ### Using the model
# The following code uses the model trained to classify each one of the tweets of our testing dataset
#
# Note that before we do the classification, we need to apply the preprocess (cleansing and tokenizing) that we have built before and extract the features using our dictionary

# %%
li = []
for each_tweet in testing_data:
    words = tweet_processor.processTweet(each_tweet["tweet"])
    row = {
        "polarity": each_tweet["polarity"],
        "tweet_id": each_tweet["tweet_id"],
        "date": each_tweet["date"],
        "query": each_tweet["query"],
        "user": each_tweet["user"],
        "tweet": each_tweet["tweet"],
        "predicted": NBayesClassifier.classify(extract_features(words))
    }

    li.append(row)

# %% [markdown]
# The next code snippet just creates a Pandas DataFrame with the results of our prediction along with some variables that we are going to use on our evaluation of the model

# %%
final_dataset = pd.DataFrame(li)
Y_test = final_dataset["polarity"]
predicted = final_dataset["predicted"]
final_dataset
# Out:
#       polarity    tweet_id                          date     query  \
# 0            0  2323119233  Wed Jun 24 23:57:08 PDT 2009  NO_QUERY
# 1            4  2066538439  Sun Jun 07 10:42:32 PDT 2009  NO_QUERY
# 2            0  2244241112  Fri Jun 19 14:29:22 PDT 2009  NO_QUERY
# 3            4  1695029080  Mon May 04 04:58:38 PDT 2009  NO_QUERY
# 4            4  1970774217  Sat May 30 05:09:50 PDT 2009  NO_QUERY
# ...        ...         ...                           ...       ...
# 4995         4  1793054749  Thu May 14 01:11:58 PDT 2009  NO_QUERY
# 4996         4  2059550344  Sat Jun 06 17:09:29 PDT 2009  NO_QUERY
# 4997         4  1932311368  Tue May 26 21:13:10 PDT 2009  NO_QUERY
# 4998         0  2203821501  Wed Jun 17 00:36:59 PDT 2009  NO_QUERY
# 4999         0  2048836007  Fri Jun 05 15:51:19 PDT 2009  NO_QUERY
#
#                 user                                              tweet  \
# 0         goofyholly  Transformers 2 was soldout today for the 12.10...
# 1         chelschaos  @AngelIbarra hope the London show is awesome  ...
# 2          BeeMusick  at the mall :/ getting presents for dia, my po...
# 3      LaBarceloneta  @msstacy13 Well, thanks for thinking of me! An...
# 4            akalata           @changeorder @askrom is now @chrisfahey
# ...              ...                                                ...
# 4995       Lysh_Here     All the tests are OVER! Its the best feeling!
# 4996  KellyJohnson85                         @midnightsunco Of course!
# 4997      chrissyx14  wondering why she is still grounded.. lol good...
# 4998  thenoblesavage  @johnhalton Yeah, wish I had said that, or sim...
# 4999       sebasluke  @barbarasafani what???? damn!! first time I he...
#
#       predicted
# 0             0
# 1             4
# 2             0
# 3             4
# 4             4
# ...         ...
# 4995          4
# 4996          4
# 4997          4
# 4998          4
# 4999          0
#
# [5000 rows x 7 columns]

# %% [markdown]
# Here is the Confusion Matrix (just reminding that we did not use the whole training dataset, just a sample of it)

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print("Confusion Matrix:\n", confusion_matrix(Y_test,predicted))
# Out:
# Confusion Matrix:
#  [[1774  777]
#  [ 681 1768]]

# %% [markdown]
# And here our classification report

# %%
print("Classification Report:\n", classification_report(Y_test,predicted))
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.70      0.71      2551
#            4       0.69      0.72      0.71      2449
#
#     accuracy                           0.71      5000
#    macro avg       0.71      0.71      0.71      5000
# weighted avg       0.71      0.71      0.71      5000

# %% [markdown]
# Just extracting the precision (with more precision....hahaha)

# %%
print("Precision:\n", accuracy_score(Y_test, predicted))
# Out:
# Precision:
#  0.7084
