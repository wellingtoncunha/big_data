# %%
import numpy as np 
import pandas as pd 
import re
import nltk 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import os
base_folder = os.getcwd()
training_dataset_path = os.path.join(
    base_folder, 
    "trainingandtestdata", 
    "training.1600000.processed.noemoticon.csv")

# %%
training_dataset = pd.read_csv(
    training_dataset_path, 
    encoding="latin-1", 
    warn_bad_lines=True,
    error_bad_lines=False,
    header=None, 
    names=["polarity", "id", "date", "query", "user", "tweet"])

# %%
training_dataset = training_dataset.sample(10000)
training_dataset
# Out:
#          polarity          id                          date     query  \
# 1014554         4  1881451636  Fri May 22 04:42:11 PDT 2009  NO_QUERY
# 1002809         4  1880247798  Fri May 22 00:35:03 PDT 2009  NO_QUERY
# 1330589         4  2015843049  Wed Jun 03 05:38:20 PDT 2009  NO_QUERY
# 421942          0  2062535957  Sat Jun 06 23:31:09 PDT 2009  NO_QUERY
# 1105992         4  1971358938  Sat May 30 06:55:05 PDT 2009  NO_QUERY
# ...           ...         ...                           ...       ...
# 885692          4  1686551513  Sun May 03 05:54:06 PDT 2009  NO_QUERY
# 177292          0  1965580754  Fri May 29 16:10:22 PDT 2009  NO_QUERY
# 892206          4  1691124764  Sun May 03 17:08:59 PDT 2009  NO_QUERY
# 162857          0  1957640696  Fri May 29 01:08:04 PDT 2009  NO_QUERY
# 788732          0  2325210817  Thu Jun 25 05:00:15 PDT 2009  NO_QUERY
#
#                     user                                              tweet
# 1014554       Ali_xxxxxx                 @SunshineeKiid no tmorro at 2:15
# 1002809   peterfabricius                           Got his full 7 hours in
# 1330589     turtlebisque                               Last day of school!
# 421942     charismitaine  Had craftime with @reading_angel, but unfortun...
# 1105992          EgoPimp  @Woodeh Yup, just tried and working fine.  Pho...
# ...                  ...                                                ...
# 885692          peihanko  @Scrawnyy NOT FUNNY RONALD. i got stopped cos ...
# 177292          yogeorge  @morganeleanor ew I know EXACTLY what you're t...
# 892206   rebecca_clemons                 gonna go get my hair trimmed. fun
# 162857          kelbdubs                                 Last day in Dijon
# 788732        nikkieniks   won't make it on time  http://plurk.com/p/13uu8x
#
# [10000 rows x 6 columns]

# %%
training_dataset.polarity.value_counts()
# Out:
# 0    5088
# 4    4912
# Name: polarity, dtype: int64

# %%
## Cleansing text
import re
from bs4 import BeautifulSoup
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

def clean_tweet(tweet):
    tweet = BeautifulSoup(tweet).get_text() # extract text from HTML
    tweet = tweet.lower() # convert text to lower-case
    tweet = re.sub('((www\.[^\s]+)|(https?://[^\s]+))', '', tweet) # remove URLs
    tweet = re.sub('@[^\s]+', '', tweet) # remove usernames
    tweet = re.sub(r'#([^\s]+)', r'\1', tweet) # remove the # in #hashtag
    tweet = word_tokenize(tweet) # remove repeated characters (helloooooooo into hello)    
    stopwords_en = stopwords.words("english")
    tweet = [word for word in tweet if word not in stopwords_en] #remove stop words
    return ' '.join(tweet)

training_dataset["cleansed"] = training_dataset.apply(lambda row : clean_tweet(row["tweet"]), axis = 1)

# %%
training_dataset
# Out:
#          polarity          id                          date     query  \
# 1014554         4  1881451636  Fri May 22 04:42:11 PDT 2009  NO_QUERY
# 1002809         4  1880247798  Fri May 22 00:35:03 PDT 2009  NO_QUERY
# 1330589         4  2015843049  Wed Jun 03 05:38:20 PDT 2009  NO_QUERY
# 421942          0  2062535957  Sat Jun 06 23:31:09 PDT 2009  NO_QUERY
# 1105992         4  1971358938  Sat May 30 06:55:05 PDT 2009  NO_QUERY
# ...           ...         ...                           ...       ...
# 885692          4  1686551513  Sun May 03 05:54:06 PDT 2009  NO_QUERY
# 177292          0  1965580754  Fri May 29 16:10:22 PDT 2009  NO_QUERY
# 892206          4  1691124764  Sun May 03 17:08:59 PDT 2009  NO_QUERY
# 162857          0  1957640696  Fri May 29 01:08:04 PDT 2009  NO_QUERY
# 788732          0  2325210817  Thu Jun 25 05:00:15 PDT 2009  NO_QUERY
#
#                     user                                              tweet  \
# 1014554       Ali_xxxxxx                 @SunshineeKiid no tmorro at 2:15
# 1002809   peterfabricius                           Got his full 7 hours in
# 1330589     turtlebisque                               Last day of school!
# 421942     charismitaine  Had craftime with @reading_angel, but unfortun...
# 1105992          EgoPimp  @Woodeh Yup, just tried and working fine.  Pho...
# ...                  ...                                                ...
# 885692          peihanko  @Scrawnyy NOT FUNNY RONALD. i got stopped cos ...
# 177292          yogeorge  @morganeleanor ew I know EXACTLY what you're t...
# 892206   rebecca_clemons                 gonna go get my hair trimmed. fun
# 162857          kelbdubs                                 Last day in Dijon
# 788732        nikkieniks   won't make it on time  http://plurk.com/p/13uu8x
#
#                                                   cleansed
# 1014554                                        tmorro 2:15
# 1002809                                   got full 7 hours
# 1330589                                  last day school !
# 421942   craftime unfortunate lack made dandy little bo...
# 1105992  yup , tried working fine . photos downloaded p...
# ...                                                    ...
# 885692   funny ronald . got stopped cos roadblock.you '...
# 177292                         ew know exactly 're talking
# 892206                    gon na go get hair trimmed . fun
# 162857                                      last day dijon
# 788732                                    wo n't make time
#
# [10000 rows x 7 columns]

# %%
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()
text_counts = cv.fit_transform(training_dataset["cleansed"])
text_counts
# Out:
# <10000x13454 sparse matrix of type '<class 'numpy.int64'>'
# 	with 68351 stored elements in Compressed Sparse Row format>

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=2500) #, min_df=7, max_df=0.8)
vectorized_features = vectorizer.fit_transform(features).toarray()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(vectorized_features, training_dataset['polarity'], test_size=0.25, random_state=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-8e9f99f44523> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, Y_train, Y_test = train_test_split(vectorized_features, training_dataset['polarity'], test_size=0.25, random_state=5)
#
# ~/Library/Python/3.8/lib/python/site-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2170         raise ValueError("At least one array required as input")
#    2171
# -> 2172     arrays = indexable(*arrays)
#    2173
#    2174     n_samples = _num_samples(arrays[0])
#
# ~/Library/Python/3.8/lib/python/site-packages/sklearn/utils/validation.py in indexable(*iterables)
#     297     """
#     298     result = [_make_indexable(X) for X in iterables]
# --> 299     check_consistent_length(*result)
#     300     return result
#     301
#
# ~/Library/Python/3.8/lib/python/site-packages/sklearn/utils/validation.py in check_consistent_length(*arrays)
#     260     uniques = np.unique(lengths)
#     261     if len(uniques) > 1:
# --> 262         raise ValueError("Found input variables with inconsistent numbers of"
#     263                          " samples: %r" % [int(l) for l in lengths])
#     264
#
# ValueError: Found input variables with inconsistent numbers of samples: [1, 10000]

# %%
from sklearn.naive_bayes import MultinomialNB
MNB = MultinomialNB()
MNB.fit(X_train, Y_train)
# Out:
# MultinomialNB()

# %%
from sklearn import metrics
predicted = MNB.predict(X_test)
accuracy_score = metrics.accuracy_score(predicted, Y_test)

# %%
print(str('{:04.2f}'.format(accuracy_score*100))+'%')
# Out:
# 72.84%

# %%
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score

print(confusion_matrix(Y_test,predicted))
print(classification_report(Y_test,predicted))
print(accuracy_score(Y_test, predicted))
# Out:
# [[953 305]
#  [374 868]]
#               precision    recall  f1-score   support
#
#            0       0.72      0.76      0.74      1258
#            4       0.74      0.70      0.72      1242
#
#     accuracy                           0.73      2500
#    macro avg       0.73      0.73      0.73      2500
# weighted avg       0.73      0.73      0.73      2500
#
# 0.7284

# %%
X_test
# Out:
# [<2500x13454 sparse matrix of type '<class 'numpy.int64'>'
#  	with 16931 stored elements in Compressed Sparse Row format>]

# %%
predicted
# Out:
# array([4, 0, 4, ..., 4, 0, 0])

# %%
def get_sentiment(tweet):

    prediction = text_classifier.predict(tweet)
    #print(prediction)

# %%
li = []
for index, each_tweet in training_dataset.iterrows():
    each_tweet["cleansed"] = clean_tweet(each_tweet["tweet"])
    features = [each_tweet["tweet"]]
    each_tweet["vectorized"] = cv.transform(features)
    each_tweet["predicted"] = MNB.classify(cv.transform([each_tweet["cleansed"]]))
    li.append(each_tweet)
#     print(features)
    
new_dataset = pd.DataFrame(li) 
new_dataset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-01e734c033c0> in <module>
#       4     features = [each_tweet["tweet"]]
#       5     each_tweet["vectorized"] = cv.transform(features)
# ----> 6     each_tweet["predicted"] = MNB.classify(cv.transform([each_tweet["cleansed"]]))
#       7     li.append(each_tweet)
#       8 #     print(features)
#
# AttributeError: 'MultinomialNB' object has no attribute 'classify'

# %%
training_dataset["cleansed"] = training_dataset.apply(lambda row : clean_twit(row["tweet"]), axis = 1)

# %%
training_dataset["vectorized"] = vectorizer.fit_transform(training_dataset["cleansed"])

# %%
training_dataset["prediction"] = training_dataset.apply(lambda row : get_sentiment(row["vectorized"]), axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-50636a91371b> in <module>
# ----> 1 training_dataset["prediction"] = training_dataset.apply(lambda row : get_sentiment(row["vectorized"]), axis = 1)
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, **kwds)
#    7545             kwds=kwds,
#    7546         )
# -> 7547         return op.get_result()
#    7548
#    7549     def applymap(self, func) -> "DataFrame":
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/apply.py in get_result(self)
#     178             return self.apply_raw()
#     179
# --> 180         return self.apply_standard()
#     181
#     182     def apply_empty_result(self):
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/apply.py in apply_standard(self)
#     253
#     254     def apply_standard(self):
# --> 255         results, res_index = self.apply_series_generator()
#     256
#     257         # wrap results
#
# ~/Library/Python/3.8/lib/python/site-packages/pandas/core/apply.py in apply_series_generator(self)
#     282                 for i, v in enumerate(series_gen):
#     283                     # ignore SettingWithCopy here in case the user mutates
# --> 284                     results[i] = self.f(v)
#     285                     if isinstance(results[i], ABCSeries):
#     286                         # If we have a view on v, we need to make a copy because
#
# <ipython-input-81-50636a91371b> in <lambda>(row)
# ----> 1 training_dataset["prediction"] = training_dataset.apply(lambda row : get_sentiment(row["vectorized"]), axis = 1)
#
# <ipython-input-80-4fbcbb541295> in get_sentiment(tweet)
#       1 def get_sentiment(tweet):
#       2
# ----> 3     prediction = text_classifier.predict(tweet)
#       4     #print(prediction)
#
# ~/Library/Python/3.8/lib/python/site-packages/sklearn/ensemble/_forest.py in predict(self, X)
#     628             The predicted classes.
#     629         """
# --> 630         proba = self.predict_proba(X)
#     631
#     632         if self.n_outputs_ == 1:
#
# ~/Library/Python/3.8/lib/python/site-packages/sklearn/ensemble/_forest.py in predict_proba(self, X)
#     681                      for j in np.atleast_1d(self.n_classes_)]
#     682         lock = threading.Lock()
# --> 683         Parallel(n_jobs=n_jobs, verbose=self.verbose,
#     684                  **_joblib_parallel_args(require="sharedmem"))(
#     685             delayed(_accumulate_prediction)(e.predict_proba, X, all_proba,
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1042                 self._iterating = self._original_iterator is not None
#    1043
# -> 1044             while self.dispatch_one_batch(iterator):
#    1045                 pass
#    1046
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/parallel.py in dispatch_one_batch(self, iterator)
#     857                 return False
#     858             else:
# --> 859                 self._dispatch(tasks)
#     860                 return True
#     861
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/parallel.py in _dispatch(self, batch)
#     775         with self._lock:
#     776             job_idx = len(self._jobs)
# --> 777             job = self._backend.apply_async(batch, callback=cb)
#     778             # A job can complete so quickly than its callback is
#     779             # called before we get here, causing self._jobs to
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/_parallel_backends.py in apply_async(self, func, callback)
#     206     def apply_async(self, func, callback=None):
#     207         """Schedule a func to be run"""
# --> 208         result = ImmediateResult(func)
#     209         if callback:
#     210             callback(result)
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/_parallel_backends.py in __init__(self, batch)
#     570         # Don't delay the application, to avoid keeping the input
#     571         # arguments in memory
# --> 572         self.results = batch()
#     573
#     574     def get(self):
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/parallel.py in __call__(self)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/Library/Python/3.8/lib/python/site-packages/joblib/parallel.py in <listcomp>(.0)
#     260         # change the default number of processes to -1
#     261         with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 262             return [func(*args, **kwargs)
#     263                     for func, args, kwargs in self.items]
#     264
#
# ~/Library/Python/3.8/lib/python/site-packages/sklearn/utils/fixes.py in __call__(self, *args, **kwargs)
#     220     def __call__(self, *args, **kwargs):
#     221         with config_context(**self.config):
# --> 222             return self.function(*args, **kwargs)
#
# ~/Library/Python/3.8/lib/python/site-packages/sklearn/ensemble/_forest.py in _accumulate_prediction(predict, X, out, lock)
#     465     complains that it cannot pickle it when placed there.
#     466     """
# --> 467     prediction = predict(X, check_input=False)
#     468     with lock:
#     469         if len(out) == 1:
#
# ~/Library/Python/3.8/lib/python/site-packages/sklearn/tree/_classes.py in predict_proba(self, X, check_input)
#     929         check_is_fitted(self)
#     930         X = self._validate_X_predict(X, check_input)
# --> 931         proba = self.tree_.predict(X)
#     932
#     933         if self.n_outputs_ == 1:
#
# sklearn/tree/_tree.pyx in sklearn.tree._tree.Tree.predict()
#
# sklearn/tree/_tree.pyx in sklearn.tree._tree.Tree.predict()
#
# ~/Library/Python/3.8/lib/python/site-packages/scipy/sparse/base.py in get_shape(self)
#      78         self.__dict__ = new_matrix.__dict__
#      79
# ---> 80     def get_shape(self):
#      81         """Get shape of a matrix."""
#      82         return self._shape
#
# KeyboardInterrupt:

# %%
list(training_dataset["vectorized"])[0]
# Out:
# <10000x1500 sparse matrix of type '<class 'numpy.float64'>'
# 	with 53223 stored elements in Compressed Sparse Row format>

# %%
https://stackabuse.com/python-for-nlp-sentiment-analysis-with-scikit-learn/

# %%
corpus=[]
corpus.append({"tweet_id": 123, "label":"test", "topic":"tesst"})

# %%
type(corpus)
# Out:
# list

# %%
dict(training_dataset["cleansed"]) #.to_dict(orient='records')
# Out:
# {1014554: 'tmorro 2:15',
#  1002809: 'got full 7 hours',
#  1330589: 'last day school !',
#  421942: 'craftime unfortunate lack made dandy little book -- yay excursions bookbinding !',
#  1105992: 'yup , tried working fine . photos downloaded pc . excuse network mac pc',
#  350148: "never use internet self-diagnosis . told 'm pregnant",
#  1127789: "n't think weather could better around today ! shhhh ... n't tell anyone n't live . think always rains",
#  559828: 'oh lord , really time spanish basically ? come !',
#  948221: "'s cause green day freakin pwns",
#  1593078: "'s awesome ! movie comes , sure let know . look big screen",
#  405927: "adios moe ! lol ill join . 've meaning start running working . n't : \\",
#  527995: 'hey 404s make home page !',
#  738298: 'feeling really faint',
#  59840: 'wonders weekend half already .',
#  634530: "ohkay thankyou 'm bummed n't get meet today though parents said '' raining hardcore ''",
#  1421338: 'finally hotel',
#  1537875: 'css globe finally switched buysellads.com go advertise ( via',
#  10196: "driving i-192 orlando seeing closed businesses : / . 's pretty depressing fb",
#  1371940: 'arabsodmg heeyy whassup ?',
#  815607: "well 'm re-obsessed patd ?",
#  1258490: 'back workouts san antonio ... time dinner ! im focused mannnnnnn !',
#  627794: 'andrew feeling better ! wish hanging jocelyn & james sitting around guess night ...',
#  1456692: 'go shopping going wembley saturdayy !',
#  647037: 'hope get well back work soon',
#  544939: "bored , need friends near want stuff . n't even want play normal video games",
#  1358542: "sounds awesome ! ! 'm happy two also , know paparazzi video talking .... weird .......",
#  1297931: 'missed !',
#  1585433: 'row 22c , flight 679 .',
#  1334335: 'excited rest furniture coming today',
#  1360795: 'kind look like caterpillar',
#  356861: 'cassie work 4-12 sad sad timessss',
#  916066: '& laying back fox truck drive race ! lol',
#  865030: 'great live show last time seen ya !',
#  87480: "work mother 's day",
#  737611: "thinking family & friends nortel . delisted tsx monday . 's end game , folks .",
#  766599: "oh ! ! hope n't get rain seen enough stuff last years come lol 6am exist ? lol",
#  441511: "well 's weird ... every time try opening blog , browser freezes closes due error",
#  565029: 'amazon fail decided buy mp3 downloads morning gift certificate . charged without asking',
#  1227356: "says sabi nga nila `` place everybody ''",
#  1408897: '- wow love ur hairr nice fringe aha mi sister likes takin pics 2 : x',
#  298031: 'hate brought . always feel like little girl',
#  906051: 'yay .. sherbert chocolate ... nutritious',
#  846259: 'toys ! !',
#  1283229: 'bump ? see pretty face',
#  279187: 'awesome weather ! watched new moon trailer , totally wait november ! english exam tomorrow',
#  76563: 'cat pased away today thats really sad day today ! ! suck ! ` believe god !',
#  275981: 'survived 1st day back work.i hav loads planning 2 done half term , fair , wan na sit sun',
#  490150: "'m sheffield tomorrow evening enjoy leeds !",
#  613256: "hah ! would kill figure ! 're age ( think ) 've got fat saggy old lady thing going already .",
#  850901: 'ur beautiful ... love style ... watch keeping kardashian ! hope u reply tnx',
#  869349: "geeky morning ; heroes video ( lionel luther , yay ! ) watched tng episode `` darmok '' virgin . one favourites",
#  114975: 'chillin crib bored mind someone rescue ; )',
#  1013390: "n't told 've pushed lately . health condition , 's remission , take advantage .",
#  239570: 'good today ...',
#  191001: 'shoes hurt feet hurt ?',
#  1554528: "regret teen years ( song called `` candy ? '' ehhh ) importantly , would marry ?",
#  311450: 'dads',
#  312900: 'wrappin projects daap . hoping get sleep thursday .',
#  385335: 'saturday university',
#  1450401: "stank u b. left da cd 's home didnt get 2 listen 2 . hopefully manana",
#  1483667: 'listen dougie',
#  255540: 'back home .. beautiful ride .. awesome day ! hope guys say ! need .. tomorrow monday .',
#  1069979: "oh ! new name ! admit swamped & n't notice ! name change ?",
#  1451431: 'watching spongebob ! ) one favorites feel would never get tired !',
#  475220: 'want play halo',
#  814702: 'good morning lovely people',
#  1272885: 'good work .. highly impressed',
#  675461: 'missed storm ! ? ! ?',
#  846826: 'kind .',
#  455547: "'m bg work nancy meyers film next 3 days , nothing",
#  1228536: ". something better.i 've wanting watch blade trilogy",
#  1221940: '- nice dress , look gorgeous . congradulations award way .',
#  980: 'bedtime , school tomorrow , still books broke suckssss',
#  1530746: 'love makes us act like fools . want go paris ( c )',
#  1429798: 'driving back helen ! yay . shit . texting driving ...',
#  557981: 'trying figure twitter',
#  580433: 'well mike ... didnt win atari 2600 ebay ..',
#  1278412: 'yes ! thinking checking salt ...',
#  800773: 'thanks next time shall better prepared lol',
#  683495: "nothings f'ed . need talk hahahahhaha ..",
#  219599: "damn , 's stock legit site",
#  374177: 'red rover red rover , many times gon na drop blackberry till night ?',
#  870250: 'seems projecting headaches people . warned .',
#  677: 'wan na rock maxi dress @ coachella , lacking funding',
#  130997: 'miss baby already',
#  215480: 'writing extended essay',
#  390551: 'love siddham/bonji , wonâ\x80\x99t encoded unicode quite',
#  860145: 'ignored smack talk voicemail',
#  287530: "dang ! missed heights pgm wednesday night . supposed re-air yesterday , n't .",
#  520151: 'working - sad . lost good friend weekend greatly missed sammer !',
#  750834: 'beginning effect yes ! though books unfortunately',
#  1520350: 'thanks',
#  1295994: 'oops , posted experiment answers everyone see .. ( richardwiseman ) .. ignoret theseunless richard .',
#  464831: 'boooo -- ya live ? u take time !',
#  348464: "niã±os cobardes ... make cry ! ! ! `` fuck sistem '' xd â\x99¥ sid ...",
#  488962: 'yikes mom , know feeling . mom stroke week got promoted .',
#  93619: 'heart sooooo sad soul joyful ? ?',
#  896296: "busy yet awesome weekend ... cut cleaning half - continues ... grateful friends fam - y'all rock world !",
#  695466: "samatha gon na get busted spending dad 's credit card",
#  894030: '- love !',
#  429099: 'want heroes come back',
#  37908: 'rofllll , least looks better adam lamberg . miss lizzie mcguire .',
#  877857: "got home . 'm tired . =p tonight sooo fun . lcbo paper bags , bacardi coke . =p nuff said . good night world !",
#  719358: 'watching fox hound haha yah bein cute took pic',
#  939796: "'re welcome ! sorted end weekend goes plan , posting 's left",
#  746224: 'freaking racquetball cant even lift cup drink',
#  1404960: 'celebrating cheer coaches retirement',
#  1525036: "yes - hols schools think 'm back work 18th august . nine half days still go !",
#  1564405: 'mostly likely ; going bed right . remember ; ; lines , vines trying times stores tomorrow .',
#  39821: 'loading car tetris style ... ran room',
#  78985: 'missing boyfriend',
#  1207127: 'mtv movie awards !',
#  19174: 'wish',
#  1399564: "eyes wide open fire away ... feel free call cell phone . 'll dm #",
#  762483: 'wanted put pictures wall',
#  824987: 'finished cleaning fridge straightening cupboard im even home ! omg ! ! ! im getting paid ! luv friends',
#  1517996: 'yep definitely hear . speaking kettle seems like good time cuppa tim tam .',
#  1332808: "januel , betina , mica , others : safe taft ! n't forget wash hands always",
#  413180: 'havin probs sims3 . wedding party , missed wedding ? miss ?',
#  587418: "iphone 3.0 upgrade lost half kate 's apps , family tech guy 'm getting blamed",
#  869453: "gun slining straight shooter - like guns ? 's interesting ...",
#  1432671: 'hopee good rehab ! xd bad !',
#  230998: 'feeling great tonight back tomorrow !',
#  104945: "got home ... pretty tired ! call n't text cause phone 's messin",
#  722384: "man 'm scared . father die today",
#  1172406: "'m making tumblr !",
#  415069: "oh wth ! miami 's weather crazy ! still able go ?",
#  1186741: "raised southern baptist- guilt thing linger tweet , 'd like think 's enc 2 twittersphere",
#  195226: 'good internet sucks wbu ?',
#  364300: 'paper cuts suck , cardboard cuts suck worse',
#  998732: 'find bones soundtrack itunes , borders amazon -',
#  1092756: "'s feeling , ha ! well , hope 's boy",
#  491930: "'s raining ..",
#  1551904: 'cool interview wit nicki minaj . see !',
#  586124: 'hating finals',
#  1287293: "haha yeah ! 10 % might true 's probably personal experiences sun reporters .",
#  557267: 'able call back ? doctors diabetes problems dont worry cant though',
#  524330: 'dont understand keep thinking boy broke years ago hes still head',
#  347697: 'make project germany france .- !',
#  1013195: '4 hrs long weekend starts lunch take least 1',
#  1495821: "way [ ] job , called talk ` n bout `` mommas 'm bored '' . sooo go ` n entertainment . ily daddy",
#  1431906: "welcome back . good luck job search assuming 're looking",
#  1476419: 'lol ... jst saw lol .... course',
#  814520: 'myspace uploading pics thousands already',
#  1545187: 'world , slow get run . thanks support',
#  1394055: 'radio disney europe',
#  1148267: "odd day , lots positivity . talked old friend 3 hours today . good times . tomorrow 's possibilities make smile",
#  589680: 'yo happened 2 bday shout ? 40 min n bday cheer dub .',
#  951045: 'ur stunning girl planet & love ! < 3 skye way australia called yesterdayd',
#  688840: 'great bday , def paying right ... thanks everyone coming !',
#  657340: 'going miami weekend ... lol oh well',
#  1317705: "family 's last name odango . thought 'd sharrreee",
#  74097: 'sorry got back !',
#  1350576: 'time blow away lord ?',
#  763398: 'grrr . nail polish keeps chipping even though put top coat .',
#  1017095: 'lovers , .',
#  921959: "happy mother 's day moms .",
#  33798: 'tired',
#  398486: 'oh night , locked house 2nd night living ! sorry babs',
#  1259618: 'hey hot stuff !',
#  1032656: 'happy 38th birthday , kevin ! great day .',
#  628452: "boo ! 'm home already . 3 a.m. comes early",
#  401085: 'back working',
#  749909: "ca n't believe class n't yet ! whaddafuck !",
#  1130484: 'time ... deal',
#  1384088: 'viv got throught 1st auditions !',
#  486405: 'pretty much hating today . many smart people already answered thesis question . damn . need think',
#  224464: 'another sarurday nite fucked ruins theres originality left world',
#  228576: 'face hurt soo bad hail drew 1',
#  1158804: "wheyyy , dragon plateleg drop ol ' iron dragons .",
#  1527657: 'haha . yea ?',
#  99602: "n't measure affluence car drive , fact n't laser cutter yet",
#  152676: 'stars tonight',
#  267092: 'cold .',
#  1403137: "devon looking stylin ' jason amy 's wedding ! got super cute pics",
#  1117230: 'helped friend get blackberry . lots questions coming ...',
#  195847: 'three days . three weeks',
#  3238: "except missed last weeks s.lee 's gone iplayer",
#  1199021: 'pleasee view pictures > > ; ; ;',
#  58355: 'aww ... really named ?',
#  754033: '- want sun',
#  629419: 'could worse , could d-backs fan',
#  355561: 'typical stops raining get home : @ im still soaked lol',
#  594921: 'oh joys freelancing ! ! told time change rehearsal . two places time',
#  445270: 'still driving .... ahhh ! going crazy ! ....... tummy hurts ...',
#  1254501: 'sent via facebook , bridal shop got little busy earlier',
#  1246018: "want drink ... 'm see'n shot somethin near futher",
#  1024801: "morning ! eep ! ca n't wait ! 'm super excited ! !",
#  771134: 'hi lyyyyyyyyyyyyyysssssssssssssss delete happy birthdayâ´s tweet ? favs . iâ´m sad !',
#  1300778: 'video riley kevin',
#  1529552: "'ll let know markie 's night ended",
#  1104725: 'see . looking forward great time miami !',
#  391849: 'ugh ! looking forward cleaning tomo sucks !',
#  816235: "crowdspirng everyone , evil ? n't think quite , ... hang ...",
#  1260002: "u 'll great ! u know !",
#  661114: 'got yelled hot topic employee calling gauges gauges instead plugs ... im really upset',
#  860517: 'smh lol w smiley face',
#  1264541: 'love david ! , wait great day shout .',
#  783851: "'m today",
#  1137207: 'use protection',
#  1480350: "woke sexiest vision ! eeep ca n't wait till summer vaykay fuck summer school !",
#  1551526: "really likes fast food ... 's right ... 'm afraid admit ...",
#  1502341: 'finally changed twitter name .',
#  1373502: 'like holds hand',
#  732826: "personally , think high ranking iranian politicians/clerics n't want give system using people fight power",
#  812926: "thanks , tony ! 'm trying ...",
#  748598: 'feel like foot gon na swollen like forever',
#  175722: 'sounds awesome , wish could go way could afford fun !',
#  113: "n't make sense , suicide thing . refuse believe actually happened .",
#  878880: "asked 's buckeye several years ago . 's gon na take soon .",
#  569512: 'dunno mines eyes fell still living',
#  1582724: "good morning y'all ! 'm potato couch",
#  890533: 'think would raelly nice could follow artists alerted whenever create new adoptable .',
#  694481: 'sad jenson button lions .',
#  1471115: "haha 've enough year thanks hehe .",
#  1594026: 'nice picture , trap ! !',
#  350596: 'woops ... wet/cold weather spoiled weekend plan',
#  312: 'su yin huen tweeted feel unbearable guilt . made staff cry',
#  386993: 'catching college work ! ! lol',
#  1212184: '- shake hands mister carter us',
#  514528: 'oh , see isâ\x80¦',
#  711305: "'s last one",
#  44561: 'back using plain old digsby alpha flat-lined .',
#  1043545: 'youre welcome * muah *',
#  528769: "'m okay mama work thinking bout daughter ... stomach virus",
#  1397036: "`` ah haha '' means end conversation .",
#  1573838: 'rescue anytime jordan ! like new pic',
#  1554029: "leighton meester 's clearasil commercial",
#  92175: 'got brainbone daily question wrong ! -',
#  652674: 'got appointment see dentist , till tuesday',
#  1385780: "youâ\x80\x99re los angeles area & 're looking real shoe repair expert , find ! !",
#  92169: 'mothers day cool . miss mom',
#  1168911: 'lmao ! gutted man , oh well , pay good , worth right ?',
#  127056: "friday work go hospital 'd think one person work would ask went , upset near tears",
#  962417: 'didnt really much revision today prob isnt good idea seeing exmas tomorrow ... ah well ill fine !',
#  969230: "grass fed ( veal ) liver first time life ! nottt favorite , 's good next time 'll hide beef burger",
#  752165: "'m sick hearing jon & kate . grrr . 'm concerned divorce plus 8 .",
#  1583037: 'birthday cake g2 towers please ?',
#  453227: 'missing',
#  270670: 'hate waking 6',
#  1256424: "ty recommended jayne 's work , yes well acquainted .",
#  987646: 'school , home , store , food , myspace , target ( water ballons ) , shower , sleep',
#  1282408: "awe tried commenting youtube n't posting .. seems maintenance today didnt work .. ill try later ! cute vid !",
#  490277: 'late honey going 9 hours ..',
#  796435: "ca n't believe 's still half hour left work",
#  341310: "'m bored",
#  853048: 'know quote used cia un-but point remains',
#  24677: '2 ..... im proubly gunna run errands',
#  157818: 'imbed earliness ?',
#  558341: 'hi , cant make ... shattered',
#  1077125: 'thanks',
#  461680: "omg ? passed away ? 's sad . loss !",
#  275210: "fuck ; want tell feel . ca n't -sigh-",
#  190526: 'firework show lasted 8 min . thanks lot gaylord texan . going bed .',
#  853389: 'seems harmless',
#  233259: "sad 'cos skunk anansie @ paradiso 8th november already sold !",
#  789405: "n't like america stealing best friend",
#  1017307: 'new , anyone advice works',
#  1144314: 'chatting away - prob pics man !',
#  1044383: "guckst du hier interview : name ist : `` us '' ! ! !",
#  1278043: "oh yes ! 's time finally ! , hammer time ... 's pau hana time ! ! !",
#  1301367: 'finally sun comes ! ! !',
#  1155606: 'agree , need privacy fence would love see hot pics yard',
#  5706: 'argh . forgot ibuprofen',
#  1117704: 'fuuuuuuuuuuuuuuuuuuuuuuuuck @ seeing envy . get shirt !',
#  35640: "get bus , 's far nice siting lecture theatres",
#  259083: 'getting season finale hills , oh miss lauren',
#  1135124: "work finally ! ! time game ! ! let 's go magic ! ! ; )",
#  1118504: 'new business cards came',
#  467610: "morning - miserable day - shame sun n't follow us back west coast ....",
#  1419903: 'call yu mai lovinq',
#  1487208: 'donations audio xponent greatly recieved',
#  1266253: 'got ! 1vs100 awesome .',
#  966257: 'tiny coming home = ( least sol yes ! !',
#  803208: 'predlets park nanny , time constitutional walk get thoughts together . many threads weave untangle',
#  678116: "woozy . lol rummag n't really hurt damn throat raw puttin huge tube .",
#  1535381: 'change player stick one ? main ?',
#  1183701: 'hm , think , like',
#  753400: "feel damn lucky . boy n't gots year",
#  178017: "'m still trying see star trek ! 'll woman go alone . bf pretty much worthless anyway lol",
#  1152400: "section 203 204 100 % sure . gave tix 2 cousin n't lose 'em",
#  1336292: 'come call recognizing .',
#  1188640: 'hi harry',
#  851942: "red rock every day ? today new mozilla 650 castro , lot soon . let 's meet",
#  1457752: "'re never ready kids - sometimes 's leap faith",
#  275663: 'still monday theres long time wait friday',
#  625483: "'m quite sure . know survived work thanx 2 cough drops easy schedule .",
#  144484: "wish could unemployed ! ! ! lol jk fun without ! 'll probably meet sunday , 're going manch",
#  879295: "anxiously awaiting sara bareilles ' next album . < 3 < 3 < 3",
#  84266: "podcast recorded , 'll redo part audacity evil",
#  1302169: 'hey lady day ?',
#  1412937: 'idea . got call two old friends saying bought three tickets want take 3rd .',
#  817329: 'tell us goes .',
#  1169271: "'s news . n't heard , time , n't lookin .",
#  1141440: 'know ? village idiot . hanging seastar',
#  1312987: 'love getting twitter ! wanted see big deal . go queens . guelph still amazing though',
#  523566: 'extra taxes manufacturing & packing sector methinks .. passes straight consumer ..',
#  183273: "hospital .. friend 's grandma fell & broke pelvis",
#  3062: 'flu',
#  248882: 'yay supposed see january atlantic city ... never happened',
#  362279: 'know , know',
#  9583: 'biggest headache world',
#  1180987: 'mmmm dont know hungry made ! !',
#  422019: "'m confused .",
#  394724: "shot playing go ( could n't say go * pun shudder * ) thrashed ... manga makes look , well easy , do-able",
#  356708: 'shattered need sleep',
#  381830: 'upset everyone leaving today ... last night london september',
#  187297: 'silence button switch thing side broke iphone',
#  146139: 'gettin thangs together head san antonio ... wish goin spurs game lol good ...',
#  61830: 'omg pants hideous look like uniform pants , lot pockets',
#  1130290: "safe trip back home , hon - glad 've good day .",
#  438099: 'know sucks ! ! !',
#  174500: 'nope',
#  666445: 'major fire erupted friday georgia theatre , athens landmark center local music scene , police said . nooo love',
#  310170: 'music used help sleep , keep wide awake',
#  114654: 'damn hang',
#  112662: 'tummy',
#  787582: 'calorie counting help fight bulge become health conscious . 4th day realize eat ton fat calories .',
#  1200835: 'mis muchachos de one call hahaha need ! ahoritaa ! ! ! ! ! !',
#  1117148: "'ve even watched episode , clips humanfails",
#  205304: "'s uppppp tweople ? ? got done super rushing get somewhere closed early ....",
#  22921: 'phone keeps restarting . -',
#  1183891: 'finally made cape breton island , nice sunny warm must around 20c moment , living life',
#  422927: "reason tweets n't showing profile",
#  221351: 'well trying find college ..... fun',
#  1587115: 'tht ur pic ? ur quite cute u know',
#  527507: 'ok sounds great think time difference ..',
#  73259: 'another rainy day . ugh .',
#  1263628: 'amazing turkey dinner boy !',
#  81763: 'always send animated card , wanted year different failed accomplish',
#  328183: 'rollerblading fun games someone gets hurt',
#  445307: 'wow feels weird speaking people first school years .. changed much ! ! miss guys lots',
#  739394: "'m sorry know !",
#  555652: "ahaha well 'll possibly reaction , hope 's happy reaction , 'm sad",
#  606529: 'okay . buy meh awesome',
#  816788: "omg ! thats crazy iphone twins 's birthday ?",
#  875972: 'john 11-13 wed ! ! ! bring $ 7 coming see x-men belltower friday !',
#  1472014: 'thank u !',
#  1300176: 'meow',
#  610457: 'damn always tryin get paper ... problem always win',
#  1579347: 'northolt glorious',
#  385289: 'yeah - working today',
#  1359697: "anytime darls ! 'll back monday !",
#  351704: 'shady practices . bueno .',
#  1332227: 'thank',
#  1124199: "mcfly dfs advert : ' ) always makes happy",
#  1418001: 'megs : tex ! double bring jeter damon ! yanks 2 , outs bottom 9th',
#  939225: "thems plan = `` wearing make eviler '' tagline",
#  953193: "'s new aspirin .",
#  1180312: 'take easy first days first pair ! remember mbts re-soleing ! !',
#  780154: "! confess n't ! missing ?",
#  425834: "playing wii @ via 's house . homesick",
#  648958: 'cant believe leaving thursday',
#  474946: "'s probably going b sore take care ... 'm good , way work .. mondays always worst",
#  44225: 'i.want.a.guitar ! ! ! ! someone gift one',
#  1204802: 'loving oc season 4 ... rewatching disc 4',
#  771185: '( shakes fist air ) brown !',
#  1598685: 'actually choose one would say storm',
#  484161: "n't know survive living house another year",
#  412490: 'approve becoming cougar ? thanks ! kidding , think newfound support bad luck penguins .',
#  1262325: 'surprised ? really ?',
#  1271431: 'son max',
#  416866: "something .... bad ... shit list . n't know long .",
#  1257278: "classic `` get lawn ! '' old man tactic , throw cane ? j/k , uncool",
#  648211: 'done , lol . stopped wow university started year .. one hardest things ever .',
#  653711: 'cant ill tonight ! ! ! u poor sod ! !',
#  375173: 'go sleep alone tonight',
#  1260514: 'awe . got ta love boy loves dogs',
#  117772: 'able eat .',
#  838073: "'m good getting ready exams starting tmrw . haha . youuu ? : ]",
#  100151: 'rainy day yet work home day .... driving two lane hwy !',
#  236152: 'room empty , walls bare , life boxes . goodbye glasgow , good two years !',
#  33056: 'nothing happened',
#  107798: 'sucked bowling ... 66 lol went right side matter aimed ... 4 gutterballs row roflrofl',
#  4778: 'well bored wait 3 hours start getting ready',
#  646685: "dammmmmm got college monday ... 've grow used life non-stop `` chilling '' ...",
#  1378886: 'make sense . better come . really going sleep',
#  1565541: 'watch one treehill future wife sophia bush',
#  1427287: 'thats one way',
#  1590572: "thanks . ryan n't hugs embraces .",
#  371583: 'two thumbs multi task ! bored ! hubby watching scar face',
#  1386363: 'yes , thank refreshing memory .',
#  1085598: 'hop bed turn swag took look mirror said waz',
#  212713: 'dont know feels empty without',
#  1152376: 'church afternoon gawai eve dinner . gon na proudly wear ic bracelet . today .',
#  597920: 'wish tomorrow could like today . wish everyday could like today .',
#  816485: 'omg , ! ! summer going best .',
#  335996: 'hope lump big deal lmk get checked . , hes really lazy',
#  654816: 'aww sorry hear lost sounds like made smile . beats old job day , right ?',
#  1405303: 'u follow plz reward post pics take monday',
#  549634: "'m sleepy ! ! ! ca n't fall asleep ever moments ?",
#  1235560: "'m getting pumped andy roddick 's match today ... , ever get see sundown ! ... hoping sneak today",
#  559871: 'missing show first day school .',
#  520851: "good morning ! 's overcast rainy . looks like 's going way much week .",
#  1513485: 'watch ducktales and/or aladdin everyday ( even read ? haha )',
#  467463: "stuff gone . serious concerns `` 's earning keep '' . 's issue",
#  79567: 'hotel internet got ta wait til get home tomorrow til get ahaha .',
#  15457: 'stupid umd a+pii prerequisite messing summer !',
#  1232725: "'re google girl ! awesome !",
#  745077: "n't get see u mansfeild",
#  709944: 'wish working ipod player',
#  1480274: 'yep',
#  761815: 'wish little kid , skinned knees easier fix broken hearts',
#  567838: 'ran mile .. coulda ran ankle actin',
#  302461: "yes , unfortunately lvpd wo n't let",
#  806014: 'finished spanish good !',
#  479814: 'sorry hear hope recovers soon . take care , love .',
#  976553: 'working first mission video . fiestamovement',
#  52697: 'spent hr hte phone best mate spain , miss much good excuse org weekend see family : od',
#  1208788: 'sooooooo exhausted ! took 2 half hours move rooms : need lunch , mi goreng',
#  909792: "happy mother 's day moms !",
#  1169373: 'sunbathing refuse get sunburned today .',
#  883039: 'found amazing song : outsider band called daylights . mmm',
#  63571: "still ca n't sleep . sleeping disorder insomia whatever people call , ,it really sucks ! !",
#  1194257: "think finally come close sleep .... 've awake 24 hours nite nite !",
#  399881: "perfect . wants . n't want . want . n't want . wahhhhhhh",
#  4307: 'oh boy . get got field tomorrow . small planes fun .',
#  782220: "'s difficult get recycled leather . & would n't feel good getting new stuff . poor animals",
#  928732: '! ! !',
#  395776: 'made pasta ... awful',
#  603563: 'always right path seems hard ? ?',
#  1344457: '- well deserved attention !',
#  991270: 'ready new week ! unstoppable',
#  516014: "actually 'd probably laugh , right . 's shame 're land oz",
#  428253: "raining , think 'll stay home ...",
#  32681: "well 's inspiring ... haha",
#  1383308: 'mum dad way home vegas yay',
#  83624: "upset ! ca n't text jessica",
#  270770: "favourite paradisio moment : one giraffe put head another 's stream urine drank . refreshing ! video fb",
#  233619: 'would rather pub sun .',
#  997274: 'looking info wolfram today : foundation reality & nature information key question',
#  377534: 'europride parade rain ! fun !',
#  1168523: 'good morning ! ?',
#  1029528: 'looooove princeeeess ? baaby ganamos :',
#  1413409: 'hot dog ! ! ! catching fire arc arrived . goodbye , family . perfect timing 48hbc . big : : : mwah : : : kg .',
#  571111: 'simply badass yet waste time',
#  1217237: 'musicmonday alasdair mac colla- clannad .. keep irish music alive',
#  917611: 'ishra ! ! haha , cassie ventura ? ... haircut ! yesterday beat music awards ?',
#  1261244: "tell dance , maybe 'll let get pants . haha",
#  363750: 'getting ready wwdc ! sucks ! !',
#  871150: 'finalllly home . sleeepping ! awesome job ... thanks relief cleaning wade ! wake !',
#  1121380: 'fun see hi michel . housewarmings ... sounds like years ago',
#  936557: 'hope flu two year ago four mouth ulcers . four biiiig ones ! felt like dying x',
#  179293: 'wow follow friday havent tweeted ... fail . nobody followed today dble fail . * suicide *',
#  5028: "poor . finished work . 'll get day .",
#  1550834: 'woooohoo ! go lakers !',
#  1230869: "love much would amazing rplied . 're going amazing last song x",
#  444556: '- nooo ! dont want miley',
#  212022: "hey ! sorry got ! 'm sick weather hot kind cloudy ! bout springfield ?",
#  680520: "ca n't call parents",
#  681834: "'m fighting sleep moment : 7am hard work 12 hours . nearly ...",
#  406945: 'nopes live scotland youtube sucks jonasrothersbackonyoutube',
#  28167: "greets everyone . great weekend ? coke 'n chips . couch potato ; ) back work tomoz",
#  456801: 'sick & feeling like shit ! make feel better pre-ordering ep smartpunk.com , and/or teleporting , kthnx ; )',
#  1204244: "good day.did respectable amount yard work , grocery shopping ( matt nathanson musak ? nice ! ) , dog walk , bbq shish-kabobs & beer.g'nite",
#  211699: 'probably startingmy temp job amortgage loan processor week . excited',
#  1142405: "'m fine cavs - sympathy anything needed , thanks . done talking though .",
#  1218974: "'re welcome !",
#  434381: "going hardest thing ever go whole life , thank god strong 'm afraid would fall .",
#  965393: "thanks friends . see , 'm spoiled mountain views .",
#  446718: 'stop listening new sounds album ... , wont . reviseeeee ali',
#  117389: "thanks , could n't test idea , gold account ran ca n't renew end month",
#  616543: 'trying get name called 102.5 .... still luck',
#  729919: '` still stuck chapter 1',
#  773494: 'laid drafting job due recession ...',
#  1415895: 'ahaha totally eves dropped tweet knew mustve referring ahaha gahh ! !',
#  1588085: 'put smile ur dial , ill see yu little good bye todaay ill see againnnnn !',
#  894016: 'wan na come',
#  706076: 'sad',
#  352807: "hahaha issues 're perfect , 'm generally indecisive colours",
#  498927: "holidays ... maybe 2 weeks month . since patient , n't really hace holidays long ?",
#  1409284: 'omg ... sooo used look o.c .',
#  522498: 'mum packing childminding measgers tabby , liam , kiwi , broocklyn , ruby , mel , blondie & jemaine',
#  342444: 'isplayer died ! sorry',
#  1546114: 'wan na top ?',
#  1481934: "yeah , thought johanna one 'd silly mail mail mel .",
#  1495501: 'great minds think alike',
#  261220: 'home ... missed almost hills ! grrr . needs repeats & feel like crap . needs tlc sneezing damn day . bawl',
#  313272: "burnt , dry toast skimpily-filled sandwich . n't think 'll bother going o'briens food",
#  885051: 'may going sneaky pint still probs dm email ciaran stoodthere.com',
#  1123435: 'woo , convinced buddy jon buy coffee tomorrow morning head morrisons',
#  434710: 'upset tummyy .',
#  1022768: 'fun utah ! really need hangout get back ! ! miss guys',
#  210207: "oh em f'ing geeee never knewww ! never would thought everrrr lifeee ! soooo crazy wannna fxckin cry lol jk wow",
#  1057714: "hey , right 'm watching fred youtube !",
#  26985: 'way back shitty microwaveable food . bye escanaba !',
#  80315: "pissed wo n't see maki ( mom ) mother 's day",
#  569902: 'sore throat',
#  554912: "picture n't work",
#  1363921: 'raving mix night x',
#  1565642: "though n't showtime , 'm behind . n't seen season 3 , spoilers ! waiting buy",
#  611960: "ca n't beleive missed meeting never knew ! one told hopefully another time ...",
#  145578: "n't know friend huge fan lane bryan think make sports bras .",
#  1301401: "always look gift , even wrapped sandpaper , 'cause",
#  1406117: 'wearing plaid pearls country club',
#  1446178: "'re welcome",
#  1073813: "'m extremely addicted twitter",
#  847607: "twitpic fail - 're know 'll envious set get pro 'm trapped dan",
#  662233: 'oh * tear * miss pret',
#  1373690: 'watch lost anytime : ( seasons ) | lost wftb | enjoy everyone goodnight !',
#  815557: 'hoping productive today , working afternoon ... mommy & p time',
#  63610: 'blah forgot read huck finn',
#  820428: 'decide change better ! whole new',
#  577868: 'soo look exact ones lol . thats american idol . came . mom didnt let get em',
#  30224: "oh blast ! 's young adult size",
#  897397: "lol 23 yrs know 's silas spenser david kid got screwed unique name ; )",
#  718812: 'disappointing * hugs *',
#  261486: "'s getting chilly tonight ... thought summer",
#  1439239: '- eyes looks absolutely gorgeous ! * . * amaizing ! !',
#  524064: 'share ! hungry morning',
#  792064: 'aww sucks',
#  502715: 'missy ( cat ) breathing well think may leaving soon much annoyied ill miss .',
#  557623: '? lols jk miss',
#  70972: 'sad news . make scholarship cut .',
#  75588: 'hate first 2 thoughts wake morning abt bad things',
#  1248334: 'real dream lol',
#  1472477: 'booo rain ! cold ? ? im starting take clothes buy stuff im !',
#  1156166: 'good day , faizon .. great see xero error honorary member twitter',
#  72408: "tired wishing n't agreed work today ... 's bank holiday ! x",
#  315493: 'panic attack feel like ? im soo scared',
#  953439: 'sure , great .. ill send bio well',
#  1000935: 'two hearts one beat ... two souls one shoe . ready disneyland morrow',
#  219003: 'hurt wrist ! please please please ok tomorrow',
#  302882: "uh huh . always 's major bad today .",
#  105839: 'wala parin ate may',
#  201058: 'telus bill ... dooo dooo dooo ... double',
#  1112367: "'m enjoying fact tweet sitting front panel ... .",
#  564076: 'windowless room swang beautiful storm ?',
#  1422006: "aw cool : ] sounds ace ! good luck ( ) 'd make shamazing peter pan . aaaand 's favourite disney character",
#  957444: 'chatting > > > > > > > > .. hehe , still waiting cd ordered , taking looong time ! hope comes soon ! cant wait !',
#  554301: "'ve realized finger hurts ! 's trigger hard pull",
#  1038456: 'really happy right',
#  252836: 'email number , one',
#  380581: "live around 5hrs sleep night . caught load slept 9hrs feel like 've got biggest hangover ever",
#  1537976: 'nice day today ! watched red cliff cinema',
#  562110: 'hmm tinnitus . sucks .',
#  730192: "day 'm gon na time fix . maybe time never come .",
#  708360: 'sound bored .',
#  81577: 'redsox lost today sad moment',
#  1463600: 'empire sun frittenbude',
#  1221788: "`` must forget ? '' - > gary",
#  1491860: 'wow .... wan na know .',
#  774729: 'gay homophobe ... saddest kind booooo .',
#  1190860: 'like new pic . ?',
#  96025: '( love & uses james blunt - mistake adverts ! instrumental )',
#  492073: "wedding vegas ! 'll marry wrong guy maybe ! nando sad panda .",
#  511796: "flexughh ... night . sorry i'am trip customer meeting early next morning . 480km go ... 30.06.09 !",
#  59153: "* sighs * nothing makes feel poor planning buy something n't got money .",
#  237191: "oh pedrosa .. happend ? 've waiting two weeks race ..",
#  129513: 'keep seth home school ... sick little boy ... poor baby',
#  951562: 'hey girl ! ! think got video drunk think cool lol',
#  199456: "work till 730. still sick panda n't sleep well . sigh . need something cheer .",
#  646759: "hate nightmares . especially mornings 'm alone gareth gone work love & miss much though ... < 3 xx",
#  1369841: "fun fact 've learned : n't piss musician , write song break ... 'll come back something worse .",
#  1534521: 'person awake house & incredibly hyper . ran place 3 minutes & jumped room cleaning frenzy . whooo',
#  950606: 'fact , quite catch',
#  1024710: 'penn station - west hampton bound',
#  1500617: 'yay ! ! u cumin philly',
#  186399: 'laying bed sidda hopper greggy bear ... wish gregory steven .',
#  185399: "gene ! 's super sad face oooooooh nuggets !",
#  1137729: 'gon na make chicken terrayiki benihana style ! ! fave.yummy',
#  1425626: 'got perfect solution problems',
#  401356: "want sims 3 prolly wo n't get till christmas oh well .",
#  1105848: 'meeting youth pastor iron things hard things summer book study !',
#  875767: 'watching britains got talent ...',
#  255370: 'kings leon rip girls heart',
#  902143: 'listening distorting code spinnerette cant wait get hands full length',
#  1072753: 'hmm , looks like spymaster public beta . nevertheless , thanks invite .',
#  1485221: 'uk babe sunday nearly monday coming sooooooooon',
#  945198: 'waitin mi madre st.francis ... get iron dosage shyts crack yo loll',
#  459228: "wish tv n't one townhouse living ...",
#  576454: "'s raining 'm tired need retail therapy",
#  733960: 'ugh dont wan na work today',
#  1176149: 'haha well pretend chelsea',
#  406660: 'interesting site chrome build , mac webkit test failed link :',
#  1415879: "finally made . 're soooo high ! ! ! ! excellent view though . chuffed",
#  906128: 'hungover ......... still bed ! ! ! ! duvet day 2day thinks ooh may start desperate housewives watch new dvds richard xx',
#  930470: 'service started rough , ended much better . word well received .',
#  654561: 'today , final end netizen , 8 years life',
#  211213: 'miss , ryan xo .',
#  1050024: "way baton rouge ben 's best friend 's wedding . long car rides toddlers awesome . fox hound rocks !",
#  1579920: "'m blogger , 's ?",
#  355347: 'wish knew 3 chords guitar',
#  257234: 'ella got farmers burns . spf failed .',
#  783601: "uh um , ? * tears rolling face ... n't u miss ?",
#  375170: 'dont know 2 get',
#  187602: 'hope return tournament oahu next year . sad fields open ended .. sbs .',
#  238041: 'fighting animals outside woke way early .',
#  71218: 'work today dont feel good either',
#  1284139: 'looking forward',
#  924443: "smile pretend happy 's important feel deep within . truly happy ?",
#  201870: "'s fun sick",
#  1481044: 'wan na thank lord 4 waking morning . beautiful day ! god truly smiled',
#  226269: 'buy movie buy movie . netflix ... want buy , . dilemma .',
#  140941: 'loud drunk guys always stand beside',
#  187164: 'sound police cruiser . never get nethng xciting',
#  1135298: 'good times .. good times last night ! next time hang',
#  1387955: "'m actually polish irish . corned beef st. patty 's day soda bread",
#  337490: "imma wants baked mac bat cave .. .. . ca n't go buy .. coz pourin ' hard outside .. ..",
#  1133317: 'good night t-total , looking forward birthday bbq today officially 27yrs old',
#  601340: 'wan na see & drawings ! ! ! london far korea , live anyway , congratulations * hug *',
#  751109: "'m tired routine everyday ! ! ....... -im tired-",
#  556604: '1 purchase fp , shipped 4 days later claimed , still get luck , get info .',
#  1133384: 'ready da grand finale , homie ?',
#  1152795: "n't worry thing life , dont pretend person",
#  1145336: "yup ! 's live right . follow link & join",
#  229078: 'weed brain , none lungs fucking urinalyisis . tellin cant answer phones book appointments straight blunted son ?',
#  588758: 'pretty sure got reverse trolled . fml',
#  706548: 'cramps hurt much',
#  1596470: "taught rafael play michael buble 's sway violin . 'm impressed 's fast-learner . says 's gon na show friday party . haha",
#  235827: "henshaw left show . 'm happy either . thought gimmick , checked , & 's done .",
#  881983: 'pulling away computer .. hurts .. got ta go ...',
#  293812: "'s ? ?",
#  1584138: 'go video recipes , everything zest lime cook perfect duck breast',
#  720820: 'worked 9 hours today . back killing . sleep work 1045 tomorrow morning . want sleep',
#  279422: 'celphone crashed',
#  333671: 'back school . fell 3 flights stairs today ... could see tissue leg . im sore lucky broken bones .',
#  455849: 'think demand , plan hangout day ! one attend',
#  1583538: "thanks alot posting article back links . 'm trying start internet marketing career useful info !",
#  272989: 'please anyone youtube links mtv backstage stuff , flash upgrade nearly killed computer help ! ! !',
#  270059: "mean come ! ! ! stupid fucking colorado gets 3 shows ? ! ! ? ! ! hell ? ? 's fucking pathetic ? co az n't ? ?",
#  1210115: 'welcome back .. hope good evening .. slept',
#  712740: 'helpless situation , ppl whatever think might help . , lot kids following trend',
#  89741: "really wants sing `` wait '' talent show ca n't find karaoke track .",
#  1006912: 'relaxing',
#  1223295: 'happy 19th birthday ! ! ! !',
#  842610: 'silly dance tryout friday find today made , could wish luck & pray please',
#  688592: 'bugger , l key sticking localgovcamp',
#  1462179: 'tis going fab ... got wheeeeels !',
#  1235740: "good morning ! ca n't wait free vs undies !",
#  1306408: "looooooove duet mitchel ! sooo good ! 've fan ever since american juniors",
#  1448828: "haha `` wha ? '' . big deal carry",
#  171958: "sad people 's phones dead",
#  607767: '? u b ibiza night club n dc fri ? u . want go since concert tix',
#  735318: "thanks elliot ! 's weather fl ? 've yet really see summer yet",
#  408410: 'actually , food , though tasty sangria . alas , going find something else .',
#  1023811: 'heading lake sunday celebrate b-day , monday',
#  3507: 'immm sooooo lowwww',
#  1414060: 'loved know american teenagers age seem cool ! !',
#  1188072: 'gon na watch episodes inbetweeners',
#  1028665: ".... 'll play `` fuck ! '' ... tiffany n't say nothin 's gon na get us cut via twitter !",
#  1554679: 'soo exited ! rossettastone box',
#  597797: 'finally home . long server migration',
#  606356: "wish channel see fav christian artists dish network n't carry well 's funner concerts",
#  661341: 'revising science exams monday',
#  1185452: 'finished technology project hurrayyyy',
#  350380: "doh ! stood queue post office 40 mins post parcel 2b told ca n't work address postcode",
#  613980: "hmmm fig bit moment regressed cowered `` '' command getting less traumatized though , takes time .",
#  240996: "heyyyy made cupcakes last night ! unfortunately n't `` specially baked ''",
#  538765: 'someone got bus early .',
#  1562020: 'youre welcome',
#  885019: '- oh cute , well done , babies change world mostly better',
#  146504: 'wish central sl web-page details march land expo could easily',
#  162274: 'posted first video ... contest entry still terrible boo ... luv ur videos btw . xxxrebelrebelxxx',
#  1555957: 'watching wwe monday nite raw fatal 4 way usa network yeah baby ! john cena rocks , hostle , loyalty , respect j.c',
#  1223425: 'finally , summer sun !',
#  1250612: 'remember k ignore negative . want u respond . dont let em hook u doll . ignore ignore ignore !',
#  923350: 'putting pictures myspace',
#  1535138: "n't always easier said done ! anything big planned weekend ?",
#  1589226: 'humm , noticed shirt looks blue , , lol , closer gold , beleive',
#  685561: "'m tired study exams ....",
#  1434961: "hope 're ready paint",
#  547428: "'s missing delivery dates iphone 3g shipments ?",
#  933096: "finished watching sis . david 's damn hot cute . : > haha !",
#  592188: 'havent smoked today ... kinda sad',
#  1221942: 'exactly ! welcome twitter ! ! !',
#  1344568: "lol right time sims 3 sims 3 sims 3 ! ! ! ! ! ! ! ! ! ! ! ! ! ca n't wait fin 's post : -p",
#  279195: 'u get go playland dont',
#  73447: 'working bh ..',
#  728361: 'demand recount',
#  612339: 'oh man listening muppets show tunes , cover ears',
#  411690: 'oh sucks',
#  1562016: 'hell yes !',
#  656149: 'puked 3 times last night',
#  1189117: 'gorgeous weekend ! feeling relaxed revitalised sun - course quite nicely browned',
#  1310214: "good luck teachers taiping , hope `` bengkel '' give u much experience using 2.0 tools",
#  457467: "'m gon na sing hate life song right , hate life right escape por favor .",
#  204233: 'sun shining ! ! ! ! ! ! shame nice florida',
#  367196: 'eyes hurting !',
#  910782: 'hey ! haha , yep ! ! negative comments get reallllyyy mad ; always defend ! haha !',
#  1295345: 'noel says holla may somethin ya .. & yes shall b pickin ur ass atl airport t-minus 24 days !',
#  1535275: 'fine thank raining heavily ... plants trees getting good drink',
#  66411: 'computer broke ... fixed . lost bookmarks , reset ipod . another 80gb cost $ 300',
#  919097: 'loads little jobs today . going playing walking themed music today brickman',
#  964188: 'yeeep ! search entertweetment see finding entertaining atm ! x',
#  1319110: 'hi john . really enjoy work . nice meet . sharing music :',
#  219221: 'crying till cant cry anymore + crying =',
#  420797: "yeah , figured - 'm home , longer within 20 feet - thought supposed giving updates",
#  1137616: 'thong girl . wind picking butt day . yea ! ! mmwanted',
#  640792: 'filling tax return forms ... june 30th deadline looming head like dark cloud',
#  1249248: 'thats plan !',
#  796584: "fun times . came , made place alive , took life . 's quiet",
#  887227: 'greetings . thanks interest .extendr . keep search task austin . lucky .',
#  1132224: "thought would good `` bimmer week ''",
#  736683: "suddenly feel like getting new guitar . guitars really ugly . 're old !",
#  1151464: "- july . ca n't wait xd",
#  292740: "last 2 hrs 've rebuilding itunes library get 's phone , 3 x 's still wont work . shoot",
#  1407971: "come back bff 's house 1 week nere ! : ( l ) ca n't wait",
#  973606: 'goodnight !',
#  879342: 'post edited : kampfhund ( url # )',
#  1583156: 'baby , take journey',
#  635772: "since 's follow friday , follow man cus 's lonely .",
#  1201525: "lying outside , chillin two wonderful , beautiful doggies getting nervous time alone ... 'll throw party",
#  1492351: 'back @ beach.dc fun !',
#  1163429: 'good , thanks heads',
#  773534: "really hot ? 've cold day",
#  19285: "'s snowing moscow middle april ! 'm freezing",
#  1254153: 'killin smalls ....',
#  968261: 'good morning america',
#  94551: "lucky 're going comic-con ! 'm always late get tickets weekend",
#  160578: 'getting ready school - second maths test today also last day 3rd year ! ! next week officially 4th year',
#  1048250: 'ok get pool kids , gon na mental day !',
#  103600: "pretty upset 'm nkotb cruise ! ! !",
#  1119379: 'never got . could pm board ... name',
#  1346586: "welcome day 2 fast forward though claudia 's story . unsubscribe 're getting bored . swear 's pretty interesting end .",
#  795260: 'back mine got phone unlocked sure like though difficult use',
#  1090611: 'exactly added blog erm .. wl',
#  868097: 'going friends birthday dinner wee !',
#  1226128: 'five years uni officially',
#  367564: "keep smelling cigarettes though ... n't like part",
#  34131: 'oracle owns mysql ?',
#  819867: "yeah , course ! ! 've waitin u hours ! c'mon tell !",
#  919390: 'finally home ready bed ! night !',
#  801302: 'one heart',
#  1280407: "'ve online ticketing long time . come give try !",
#  176307: 'im going wknd sorry took forever respond realized twitter isnt txting ur updates !',
#  840867: "'ve read . however , suggestion less genetics mostly rubric , like driving test .",
#  41814: "'ll minutes . work n't feel like want around . 'm bad girlfriend . 'm selfish . hate",
#  1281835: 'upload one photo gogirl web hehehe iseng',
#  132374: ": ' ( : ' ( n't mean anything ...... knew ... even though everyone disagrees well .... know fuck life .... : ' (",
#  602094: 'tried watch sin city , got halfway .',
#  1134078: 'best entertainment weekend watching 3 year old eating chocolate ice cream .',
#  1425206: 'happy birthday hope great day , sorry hear voice',
#  438693: 'wayyy drunk last night .... lost id',
#  1474031: "'m watching attack cybermen . hope 're pleased",
#  1257122: 'iight im got seat waiting award start . find row e seat 28 thats kinda close stage',
#  822218: 'put 50 spf still got fried .... awesome',
#  1317525: "well , 's single subject ! covers whole lot , 4000 years history",
#  228190: "come 'm finding ? accidentally caught ( right ) & realized new ep .",
#  1270029: 'keep fabulous work ! wish every success new album career ! thanks keeping us entertanined',
#  137297: "bit devo 'd n't bringing chronicles sarah connor back third season",
#  417686: "god really want beer right , ca n't one",
#  464: 'bathtub drain fired : haz 1 job 2 , & iz fail . got drano ass , & iz still draining . wan na shower , dangit ! !',
#  824582: 'getting , good night everyone',
#  1172851: 'thats hard one !',
#  1174513: 'lol yeah , 2 ppl followed really knows ! people love people actually reply & convos',
#  1494940: 'feeling wonderfully joyous today ... thankful way .',
#  1519821: 'sleepy time always interrupted -.- nemonemesis',
#  397947: "sliced piece thumb 's okee uncomfortable . thanks asking sugah",
#  668274: 'smashed thumb .................... cant play xbox',
#  106427: 'season finale snl =',
#  1454760: "'s plenty sunday ! cleaning yesterday , morning - really virtuous slightest",
#  622649: 'feel left .',
#  60652: 'ok temperature sucky sucky suck suck',
#  602485: 'study ? good luck . well , avoid getting name seen bottom .',
#  1345538: 'working website ... n myspace',
#  868260: 'haha xd doubt lmfao im gooodd ( : bbyy ? lysmm < 3',
#  1096142: 'began hunting things wanted',
#  15932: "poor sick girl . luckily 's already passed . hopefully sleeps night . needs , poor baby .",
#  420667: 'sounds like missed fun roll cruise 2010 ! ! !',
#  1256701: 'bachelorette',
#  170600: "twitter wo n't let update online . update box wo n't work .",
#  241981: 'strawberry fair today ... wait june 2nd ...',
#  1060013: 'try !',
#  1594933: 'thanks ! !',
#  294917: "... 'm sorry sweetie ... hope all-right .",
#  719835: "n't crestfallen , disappointed . told mom angus/moving water pic twitpic went bit",
#  870103: "absolutely ! keep close 'll chance . home advantage .",
#  1150686: "well-well , let 's go drink irish beer",
#  849474: "love new 'do . express n't repress",
#  27898: 'wishing baby didnt sleep day go work tonght',
#  1064893: '~ lovely breaknner',
#  862871: 'david quite bromance beginning last podcast lol great show guys',
#  465098: 'good mornin ! time work !',
#  1300334: "ohhhh , lol 's okay ! ! means never go home weekends go school , cuz 'll car .",
#  243861: 'sitting car trying get onto beck rd . graduation starts half hour stuck traffic . rachel freaking',
#  98736: 'wow . never drunk . fell ledge : wow . never drunk . fell ledge',
#  529702: "yay ! 's good ! haha , birthday boring . : / fact , think got sick day . school day , though ! ( :",
#  527112: 'really ill .. x hve missed 2 days skl ... hve exams nxt week need revise .. x',
#  743068: 'still sick ! ! - think u gave ... sniffle sniffle cough cough',
#  1547847: 'spb mobile shell 3.0 rocks . period . anyone windows mobile phone go check',
#  1498385: "'m looking fiction . short stories , 'm open genre .",
#  1208095: 'thanks !',
#  1185798: "miss invincible ? 's cute",
#  133028: 'oh dear kasabian cancelled cork ... gon na many upset kgws tonight',
#  88255: 'ok , seriously need good birthday gift idea need keep getting bored time ! ! cmon peoplee . ideas ! !',
#  706810: 'sydney broke',
#  197333: 'thats sooooo funny',
#  430545: "wow red button n't work god dam rubbish digital tv - switchover weeks reduced reception",
#  132384: 'omar mad meee please talkk meee',
#  913668: "'m little late congratulations 1st tri , 's great accomplishment ... good night",
#  298529: 'headache',
#  296267: "princess problems ca n't get touch ! technology really need ! tomorrow ca n't come soon enough . night , .",
#  1531781: "522 work .. time kick monday 's ass !",
#  958681: 'never late',
#  684499: "love saftysuit . song `` stay '' sums life right .",
#  403888: 'need go sleep',
#  221409: 'big banana , coffs harbour , nsw , australia . stupid sign got way ....',
#  1369095: "back muskoka ! ! ! funn love guyss muchh ! ! ! ! lauras grad partay gunna b chain im goin city 's frotrack field",
#  1153431: ': get past security , belated birthday cupcakes trent toronto !',
#  159373: 'feel soo sick body hurting alex mad mad im ever thought',
#  111316: 'remembered go sunday class tomorrow',
#  526506: 'oh hon * gets ice heating pads *',
#  1210733: "roger , 's good , perfect travel . xp shocking 'm using ff 90 % time + installed tweetdeck skype",
#  1299601: "'m sorry ! ! remember job life",
#  673343: "bummed wo n't able enjoy suprize bonfire cuz got ta work",
#  366116: "gosh .. 'm sorry , tried worked",
#  1381082: "'s o.k thanks , restless sleep . 'm hoping 'll work favour today ! night times always worst ! x",
#  1533618: "'s crawling , sure life going change forever .",
#  860000: "'m totally excited ! looking getting motorcycle ! go epic road trip ! ! !",
#  251208: 'really gon na miss days like today',
#  1010357: "like 'm beyond confused hair senior ball tomorrow . weave option ! unless 's ponytail lol",
#  1299586: 'finally figured twitter - thanks keith',
#  384972: 'yeeep 10 ?',
#  156828: 'itss soooo cramped den . dad put treadmill thaaang cant even move chair . freedom mobility lol',
#  104888: 'wow 8 people 7 ... thats sad ... must loser something whatever',
#  1216706: "soon going trip mountain `` flã¸ien '' . ca n't wait",
#  639268: 'dam missed allstar comedy jam ! !',
#  646269: "'m tired",
#  1208343: "haha ! ror made sense since japs hard time pronouncing ' l ' !",
#  1119610: "big show tonight ! maybe 'll take weeks dance . anywho , 'm super excited `` meet beatles '' tonight !",
#  552481: 'aaaaw miss robo eye',
#  287435: 'frustration level scale 1-10 ... 13 blah !',
#  1246798: "thanks ! like 'em , !",
#  1222883: 'following blog many years , found tweeter . thank many years enlightened chat humor',
#  1155070: 'looking back , jc days worst period life . life never better last 3 years uni .',
#  530046: 'think hurts much',
#  1032065: 'amazing ! god truly going start movement music shf !',
#  865612: "'m good , ?",
#  1513667: "know clue post issues took . ca n't find label change feature request ? !",
#  661157: "'s torture ! man go wrong making burger ? ? bad one ! lots condiments help hehe ; )",
#  1447497: 'blah , sleep . nearly 3am . even sleepy , think . anyway , good night/morning !',
#  746736: 'today 100 , first time many clogged inbox',
#  1255050: "like gab ? start conversations ? talk people 's ears ? need god gabbers",
#  1093060: 'ah , lovely hope peaceful relaxing day ! truly wait see australia . x',
#  874190: 'welcome',
#  748748: 'art class killing ? !',
#  569622: 'school boringggg summer holidays soon ...',
#  659085: 'idk . thought mean people stopped following',
#  723397: "still prive next week ... beautiful well put together ladies let kno ur . * looks 's n philly",
#  1559713: 'yes ! ! ! god amazing ! ! ! glad know love ya rob ! god bless !',
#  334496: 'need find something new monday nights ! medium',
#  188303: 'im work ! ! ! yay ! woohoo ! miss ! wake',
#  1204946: 'like picture !',
#  1423790: 'like',
#  1426761: "chilled inside practically day . n't bad .",
#  396621: 'fuck someone steal phone last night',
#  1117922: 'haircut sarah',
#  794517: 'really , really , really needs tomorrow point',
#  876713: 'tks lady . feel good .',
#  1480736: "n't half bad coed softball debut .",
#  531193: 'soccer europe ( denmark ) . totally agree , depressing time year',
#  614577: '.. get chance , check brother posted . makes want cry',
#  673955: 'oh well',
#  1521363: "haha , totally ! plus 'm blonde , 's date . 's today 's task : new picture",
#  1557634: 'regis girl chatty kept saying cool cute kinda got nerves good job bangs',
#  1534117: 'cheers mate . looked phonegap looked little restrictive functionality . tried ? check iui though',
#  1442325: 'time relax ....',
#  149736: "giiiirl ? sorry n't talked usual ! 've drugged stay drugged maybe week ?",
#  610166: 'dunno , work av nights . tried promotional work ? stuff well .',
#  143290: 'heyyyyyyyyyyyyyyyyyyyy nuuu amu che haiiii ? ? ? ?',
#  155113: 'love dead phones ! hip hip hurray ...',
#  730969: "hahaha think real mc 's twitter might acting ... anxiously awaiting ntt , !",
#  1039910: 'corp. gyan - try using bitching techniques infuse prof. competitiveness among fellow colleagues',
#  1008880: 'awww thank ! cheered right',
#  262747: 'inbox = 0 ~ bills = touched ~ laundry = piled high ~ groceries = going blah',
#  137548: "n't either",
#  912381: "aaahhhh 'm excited !",
#  1410190: 'nothing beats shopping !',
#  83405: "lay head one last time house ca n't help think back fun 've . miss place",
#  271726: 'aunts complained gained weight . -',
#  741746: "sun ? ! 'm jealous , nothing clouds",
#  611715: 'hatee weather .. doesnt feel like summer .',
#  1330293: 'watched new moon trailer 8 times gon na watch',
#  1100318: 'choosing wedding pics today decisions decisions',
#  1376840: "movies @ main place since 's cheaper ? lol n't like wasting $ 11 movie could watch online xd",
#  234192: 'think appendix hurting ? well , something hurts .',
#  222617: 'tooo ! cant watch anymore',
#  441217: 'dunno local bands think drinks r cheap haha ! ! 27th think omg wish able get tickets ! !',
#  580840: 'ball hockey career might officially unless take bat dustins knee .... hmmm',
#  985324: 'cheers following ! love tee blog n vlog',
#  1235203: "relationship 'deal-sealer ' ? someone makes feel loved , safe funny",
#  1251962: "might posting anything ... 'm happy help ya ! call kathy",
#  1412160: "enjoy , 'll let know thoughts 've seen",
#  1256955: 'one jeans , .',
#  1444723: "emiiiil talin wanted tell u saw wolverine together n't go watch u",
#  1223172: 'feeling good psyche nab yayah',
#  893547: 'love montage , really interesting',
#  1175872: 'thanks ! little sis one routinely takes catchers . maybe teach head first slide ? ?',
#  104227: 'g-ma wan na back comin graduation ? whyy ? hurts says might come .',
#  1130104: 'great rest ur day !',
#  987572: '- check new name ... c/o- karen',
#  1278409: "holy shit ! would killed guy 's driver ! :",
#  784366: 'one coming 48hours non-stop gaming 4th june kya ?',
#  1471284: 'bro called aussie happy bday',
#  697628: 'havent talked whole week',
#  713429: "wan na shoot hoops 's hot outside",
#  620213: 'fed sick',
#  448715: 'urg ! missss .',
#  742021: "dave beat leki 's score .... n't want happen .... * bursts tears *",
#  1190810: "'s papa johns pizza spicy beef ! looks nice",
#  270726: 'hillhead library anyone ? im new twitter follow meeee x',
#  1030436: 'checking ur blog , & wondering never conversation . u look cute flickr',
#  963638: "n't know tf2 player",
#  1524488: "finally ! soon wo n't explain use `` sharepoint '' `` moss '' interchangeably ! ( via",
#  388475: 'hahahh turned way better expected .. didnt sing stupid girls ahahah',
#  47594: "running round things brother 's party n't even bothered come room . arse . revision time",
#  959538: 'looks nice sunny',
#  1481750: "aww miss sam ... 'll hang though",
#  1135633: 'made party chain ! ! in-laws great : -d',
#  592719: 'missed show ?',
#  706359: "mohegan sun n't shining",
#  1436679: 'big deal ? talk . probably going become bffs . oh u pop ur little man already',
#  462438: 'iremember forgot yl pw bbyxvivian ... lies ! js tried log oj . didnt work',
#  762198: 'makes mad went michigan .',
#  1352636: "'re welcome ! n't really choice ... `` existing '' sort happened one day omaha , nebraska",
#  85876: 'sad may able see daniel merriweather 3rd june thats day get back new york',
#  668957: 'love/hate relationship weather .... love rain storms , hate way make joints hurt',
#  81905: 'sabrina left messin around omegle',
#  1529952: "dear : u lum tidur ka ? know u 're bored , . see u tomorrow dear .",
#  291654: 'please ?',
#  1069664: 'mammoth weekend relaxation hot springs come ! wishing everyone great weekend ! !',
#  188642: 'whats wrong ? hope feel better soon !',
#  247227: 'least sick , dont anything . babysit today .',
#  765745: 'fucking pouring',
#  149667: 'feeling ill angry ..... good day',
#  295728: "well suppose know guys would hanging ... ? ok ... 's cool guess ...",
#  327166: 'two identical polaroid cameras .... film .',
#  1047771: 'gosh , thank !',
#  1345642: 'thanx followfriday put nice company !',
#  569949: 'getting ready go work highland farms',
#  1575362: 'hahaha whats cute girl',
#  177204: "'s raining 'm hiding .",
#  237489: 'noooooooo amazondotcom sucks knob .',
#  1248020: 'luv musicmonday awesome',
#  1564878: 'hello new followers',
#  705553: "( : â\x99¥ â\x99¥ ... love bad 's little difficult understand ... live n't easy ! ! ! â\x99¥ â\x99¥",
#  1547881: "! 've got gr8 chemistry , hope least one final win",
#  397383: 'least come visit summer least ! ! ! !',
#  1066601: 'people plaaace wan na get doowwn , put ur hands aair . drop beat',
#  328925: "oh ! ca n't make",
#  151247: 'crying cavs loss drawing next tattoo .... :',
#  1092596: '? ? ? , ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?',
#  186748: 'step one week amazing ! concert argentina ! want another concert ! ! ! ! !',
#  352886: 'making daddy soup . doesnt feel well . shelby',
#  857481: "grandson cameron named , said n't know whether `` boys girls '' funny",
#  1125656: 'yeah routine deserved win',
#  111041: 'aww andy isnt ranga anymore',
#  699815: 'ahhhhhhhhh half-eaten subway sandwich go ? ! ? time dinner',
#  1492022: "funny n't",
#  171598: "ca n't vote stopped voting",
#  1424076: "hahaha 've voting since 3 hours ago .. keep refreshing ! hope wins .",
#  722389: 'going sound dumb butâ\x80¦ got phone numbers cool kids fb texted . dumb',
#  1195335: "bbq @ alex-boy 's house back school tomorrow alex boiii rocks ... lmao",
#  1272971: 'meet guys house around 6pm , pick stuff go metrotown ?',
#  796538: 'radar shows red heading towards cant get cell',
#  1576212: 'way home .. finishing car tonight !',
#  1004794: 'wow - big day us yesterday another today think - loads traffic ! hello , bear us weather storm !',
#  1489850: "hahaha 's awesome joey hot ! thans sharing ca n't wait scranton book drive thank youuuu",
#  545586: 'ok .. watch something interesting funny ! horrible .. im running idea babe',
#  828162: 'wire show , got ta cop seasons ... im done 4 nite well 4 mornin',
#  1381125: 'dedicate 1,445 update u ! ! ! dear followers ! u rock',
#  804881: "making electromagnets doubt 'd remember- tis show biz",
#  7880: 'cooking pot roast slow cooker , helping school work , changing diaper , cleaning fat prego .. lol ! rest mom',
#  1560409: 'sitting 15 feet away king james ... think diamond cuff links',
#  1547099: 'last week ofschool summer vaca ! ! yay ! !',
#  1476276: "'ve got reserve , prefer let bidding take course might get bargain â£2",
#  1389136: 'happy shopping . hope day gets better !',
#  918196: 'congratulations !',
#  175113: 'worst headache ever history worst headaches today ! man hate !',
#  1038657: "ava daughter ? 's cute .",
#  163445: "someone 've told things would get hard .. would never done",
#  997051: "gllad hear baby n't scared earthquake , hope 's letting guys get sleep , & hot food days",
#  276925: "dude think 'm getting sick",
#  1296820: 'things capable , astound ! ! ! go hard go home ! !',
#  1434848: "well even though 's till nov , 'll pick tshirt",
#  1061919: 'finds hope knows going destroy .',
#  1207443: 'collect alarm clocks put around .',
#  383669: 'knew bad idea leave tidying today',
#  688101: "boring day . getting better 's nothing . hate midsummer . wish pizzeria open . dd",
#  518119: "dude , saw message .. 'm bridge til tomorrow soz dude x",
#  807503: "imho discreet means secretive thus `` diplomatic ? discrete = separate/individual etc ? 'm word freak also",
#  152239: 'day 2 itweb security summit starts 30 minutes , woot . much learn , little time',
#  1398080: "needless say , waiting god 's going fun little girl .",
#  781226: 'doris .. yuri .. val ... booo .. got kicked chatroom cant come back ..',
#  494321: 'great . im car-less',
#  302417: 'blah . need non-freelance , steady job badly . want work toward * something * people , work real goal .',
#  546633: 'read bottom friend kencell mad dont know .',
#  813890: 'hey miles ... got lead role student film .. ah .. dream ... finally comin true .... awesome ...',
#  1265617: "discussion via chat twitter -- 'll catch everyone exams ? 'm happy know 'm still part",
#  605589: "n't make plans la . looking . got ta see work n stuff . first , got ta sort jury duty",
#  786374: 'sleep disorder comes goes ! ? julie julie insomnia ! sucks bad ! hate ..',
#  98546: "internets ? 're completely morning . means wo n't see many tweets .",
#  1518137: '- seafood pancake . really nice ! mean yummy ! haha',
#  1359990: 'fun start',
#  126507: 'hungry . want eat hotdog',
#  209922: 'damn',
#  1133420: "hell yeahzzzzzzzz ! knew spread word 'd happen ... really mean nagging friends ... xx",
#  197823: '1 hour go shift , probably go home since still raining',
#  1397484: "'s actor",
#  ...}
